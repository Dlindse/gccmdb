# %% [markdown]
# ## Code repository for building global climate change mitigation measures dataset
#
# This notebook comprises the methodology and considerations for sourcing database entries in the global climate change mitigation measures dataset.  The dataset is an aggregation of publicly documented climate change mitigation measures from around the world. The measures are sourced from multiple databases spanning efforts on the part of government and non-governmental agencies across a range of fields.
#
# More information on each source and its original formatting can be found <a href="https://github.com/Dlindse/gccmdb/blob/master/GCCMDB%20Source%20List.pdf">here</a>
#
# Dataset sources include:
#
# International Energy Agency:
# - Addressing Climate Change Database
# - IEA/IRENA Global Renewable Energy Policies and Measures Database
# - Energy Efficiency Database
#
# European Environment Agency
# -  Climate Change Mitigation Policies and Measures
#
# Mesures d'Utilisation Rationnelle de l'Energie (MURE)
#
# Private Participation in Renewable Energy (PPI-RE)
#
# Climate Change Laws of the World
#
# - Legislation database
#
# Database of State Incentives for Renewables & Efficiency (DSIRE)
#
# World Energy Council Energy Efficiency Policy and Measures
#
# #### A note on dataset sourcing methodology and invitation to contribute:
#
# Wherever stated in the source databases we have provided the correct attributions. In building the dataset of global climate change mitigation measures we aim to be as inclusive, comprehensive, and accurate as possible in our compilation of documentation. However, there is no claim to have identified every documented measure, policy instrument or project in the countries included in the database.
#
# We invite any amendments, updates, or new submissions to the collection here.

# %% [markdown]
# ### Setting the environment

# %%
#import libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from requests import get
import json
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import datetime

import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import asyncio
import concurrent.futures
import re
import os
import nltk

#from textblob import Word
from nltk.tag import pos_tag
from nltk.corpus import reuters
from nltk.corpus import stopwords
from nltk import download as nltk_download
from nltk.stem.snowball import SnowballStemmer
from sklearn.model_selection import train_test_split
from sklearn.datasets.twenty_newsgroups import fetch_20newsgroups
""

nltk.download('stopwords')
stemmer = SnowballStemmer("english")
stop_words=stopwords.words('english')

session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)
# Out:
# [nltk_data] Downloading package stopwords to /Users/d/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## International Energy Agency Databases

# %% [markdown]
# ### How this dataset was originated:
#
# Since 1999, the IEA’s Policies and Measures Databases offer access to information on energy-related policies and measures taken or planned to reduce greenhouse gas emissions, improve energy efficiency and support renewable energy development and deployment. Delegates from IEA member countries are given the opportunity to review information in the databases twice a year. The IEA consults with country representatives prior to including new information on the public version of this site.<sup>1</sup>
#
# ___
#
# <sup>1</sup>“IEA” IEA Policies and Measures Database. Retrieved September 5, 2019 (https://www.iea.org/policiesandmeasures/)

# %% [markdown]
# ### How we got this data:
#
# To source this data we used web requests and BeautifulSoup at each individual database to parse out the country list and then construct links to each country's index of measures. We compiled a complete list of entries by country for each database and then used multi threaded concurrent web requests to parse each entry.

# %%
#get all countries with entiries in the IEA database
get_countries = "https://www.iea.org/policiesandmeasures/climatechange/"
g_c = get(get_countries)

soup_c = BeautifulSoup(g_c.text, 'html.parser')
c_list = soup_c.find("ul", class_ ="listexpander")
c_loop = c_list.find_all("label")

country_store = []
for c in c_loop:
    country_store.append(c.text)
    
full_list = country_store[4:]
print(full_list)
# Out:
# ['Albania', 'Algeria', 'Australia', 'Austria', 'Belgium', 'Bosnia and Herzegovina', 'Brazil', 'Canada', 'China', 'Croatia', 'Czech Republic', 'Denmark', 'Estonia', 'European Union', 'Finland', 'France', 'Germany', 'Ghana', 'Greece', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Ireland', 'Israel', 'Italy', 'Japan', 'Korea', 'Latvia', 'Luxembourg', 'Malaysia', 'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'Slovak Republic', 'South Africa', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'United Kingdom', 'United States']

# %%
len(country_store[4:])
# Out:
# 51

# %%
#get each countries directory of database entries for climate policies and measure, renewable energy, 
#and energy efficiency
def get_countries(link_store, url):
    for country in full_list:
        if " " in country:
            amend = country.replace(" ", "%20")
            policy_link = url + amend 
            link_store.append(policy_link)
        else:
            policy_link = url + country
            link_store.append(policy_link)

# %%
#get individual links for each entry in db

def store_pages(store, ptype):
    for p in ptype:
        g_p = session.get(p)
        soup_p = BeautifulSoup(g_p.text, 'html.parser')
        entries = soup_p.find_all("tr")[1:]
        for entry in entries:
            ext = entry.find("a", href = True)
            link = "https://www.iea.org/" + ext._attr_value_as_string("href")
            store.append(link)

# %%
#for climate policies and measure database
policy_link_store = []
get_countries(policy_link_store, "https://www.iea.org/policiesandmeasures/climatechange/?country=")
print(len(policy_link_store))
# Out:
# 51

# %%
#get individual links for each policy and measure page for each country          
page_link_store = []
store_pages(page_link_store, policy_link_store) 
print(len(page_link_store))
# Out:
# 2790

# %%
#for renewable energy
renewables_store = []
get_countries(renewables_store, "https://www.iea.org/policiesandmeasures/renewableenergy/?country=")
print(len(renewables_store))
# Out:
# 51

# %%
#get individual links for each renewable energy policy for each country 
renewpage_link_store = []
store_pages(renewpage_link_store,renewables_store)
print(len(renewpage_link_store))
# Out:
# 1494

# %%
#energy efficiency
efficiency_store = []
get_countries(efficiency_store, "https://www.iea.org/policiesandmeasures/energyefficiency/?country=")
print(len(efficiency_store))
# Out:
# 51

# %%
#get individual links for each energy efficiency policy for each country 
eff_page_link_store = []
store_pages(eff_page_link_store, efficiency_store)
print(len(eff_page_link_store))
# Out:
# 1995

# %%
#test sections
#test link

entry ={}

testLink = "https://www.iea.org/policiesandmeasures/pams/austria/name-157022-en.php?s=dHlwZT1jYyZzdGF0dXM9T2s,&return=PG5hdiBpZD0iYnJlYWRjcnVtYiI-PGEgaHJlZj0iLyI-SG9tZTwvYT4gJnJhcXVvOyA8YSBocmVmPSIvcG9saWNpZXNhbmRtZWFzdXJlcy8iPlBvbGljaWVzIGFuZCBNZWFzdXJlczwvYT4gJnJhcXVvOyA8YSBocmVmPSIvcG9saWNpZXNhbmRtZWFzdXJlcy9jbGltYXRlY2hhbmdlLyI-Q2xpbWF0ZSBDaGFuZ2U8L2E-PC9uYXY-"
response = session.get(testLink)
soup_e = BeautifulSoup(response.text, 'html.parser')
title = soup_e.find(id="banner").get_text()
table = soup_e.find("tbody").find_all("tr")
column = [t.find_all("td") for t in table]

#print(title)
entry["Name:"] = title

for t in column:
    
    header = t[0].get_text()
    
    text = t[1].get_text()
    if text == "":
        text = np.nan
    if header not in ["Country:", "Year:", "Policy status:", "Jurisdiction:", "Date Effective:", "Policy Type:", "URL:", "Description:", "Policy Target:", "Technology Target:"]:
        print("Undocumented!", header)
        
    if (header == "Country:" or 
        header == "Year:" or
        header == "Policy status:" or
        header == "Jurisdiction:" or
        header == "Date Effective:" or
        header == "Policy Type:" or
        header == "Policy Target:" or
        header == "URL:" or
        header == "Description:" or
        header == "Technology Target:"):
        
            if entry.get('URL:', 0) !=0 and header == "URL:":
                pass
            
            else:
            
                entry[header] = text
        

        
print(entry)
        
        
    
    

#print(column[0:])
# Out:
# {'Name:': 'Green book for an integrated energy- and climate strategy', 'Country:': 'Austria', 'Year:': '2016', 'Policy status:': 'In Force', 'Jurisdiction:': 'National', 'Date Effective:': '2016', 'Policy Type:': 'Policy Support>Strategic planning', 'Policy Target:': 'Framework/ Multi-sectoral Policy', 'URL:': 'http://www.konsultation-energie-klima.at/assets/Uploads/Grunbuch-integrierte-Energiestrategie.pdf\t\t\t', 'Description:': 'The publication of the Green book in June 2016 has started the discussion for an integrated energy- and climate strategy. The green book analyses the current situation and compares existing scenarios. A set of questions kick starts the public debate, which includes target setting for 2030 and visioning till 2050.'}

# %% [markdown]
# ###### Addressing Climate Change Database

# %%
#Scrape each climate policy webpage in db
climate_set = []
optional = list()

async def main():
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:

        loop = asyncio.get_event_loop()
        futures = [
            loop.run_in_executor(
                executor, 
                session.get, 
                link
            )
            for link in page_link_store
        ]
        
        for response in await asyncio.gather(*futures):
            entry = dict()            
            soup_e = BeautifulSoup(response.text, 'html.parser')
            title = soup_e.find(id="banner").get_text()
            table = soup_e.find("tbody").find_all("tr")
            column = [t.find_all("td") for t in table]
            #print(title)
            entry["Name:"] = title
            for t in column:
                if len(t) == 2:
                    header = t[0].get_text()    
                    text = t[1].get_text()
                    if text is "":
                        text = np.nan
                        
#                        print("Undocumented!", header) 
                        optional.append(header)
                        
                    if (header == "Country:" or 
                        header == "Year:" or
                        header == "Policy status:" or
                        header == "Jurisdiction:" or
                        header == "Date Effective:" or
                        header == "Policy Type:" or
                        header == "Policy Target:" or
                        header == "URL:" or
                        header == "Description:" or
                        header == "Technology Target:" or
                        header == 'Agency:'or
                        header == 'Amended:' or
                        header == 'Date Amended:' or
                        header == 'Date Ended:' or
                        header == 'Enforcement:' or
                        header == 'Evaluation:' or
                        header == 'Funding:' or
                        header == 'Legal References:' or
                        header == 'Penalty:' or
                        header == 'Related Documents:' or
                        header == 'Related policies:' or
                        header == 'This record is superseded by:' or
                        header == 'This record supersedes:' or
                        header == 'Funding:'):

                            if entry.get('URL:', 0) != 0 and header == "URL:":
                                pass
                            else:
                                entry[header] = text
                                                
                elif len(t) == 1:
                    text = np.nan
                        
#                    if header not in ["Country:", "Year:", "Policy status:", "Jurisdiction:", "Date Effective:", "Policy Type:", "URL:", "Description:", "Policy Target:", "Technology Target:"]:
#                        print("Undocumented!", header)
#                        optional.append(header)
                        
                    if (header == "Country:" or 
                        header == "Year:" or
                        header == "Policy status:" or
                        header == "Jurisdiction:" or
                        header == "Date Effective:" or
                        header == "Policy Type:" or
                        header == "Policy Target:" or
                        header == "URL:" or
                        header == "Description:" or
                        header == "Technology Target:" or
                        header == 'Agency:'or
                        header == 'Amended:' or
                        header == 'Date Amended:' or
                        header == 'Date Ended:' or
                        header == 'Enforcement:' or
                        header == 'Evaluation:' or
                        header == 'Funding:' or
                        header == 'Legal References:' or
                        header == 'Penalty:' or
                        header == 'Related Documents:' or
                        header == 'Related policies:' or
                        header == 'This record is superseded by:' or
                        header == 'This record supersedes:' or
                        header == 'Funding:'):

                            if entry.get('URL:', 0) !=0 and header == "URL:":
                                pass

                            else:

                                entry[header] = text    
                        
                        
        
            entry["data_source"] = "IEA"
            
            columns_complete = set(["Country:", 
                                   "Year:", 
                                   "Policy status:", 
                                   "Jurisdiction:", 
                                   "Date Effective:", 
                                   "Policy Type:", 
                                   "URL:", 
                                   "Description:", 
                                   "Policy Target:", 
                                   "Technology Target:",
                                   'Agency:',
                                   'Amended:',
                                   'Date Amended:',
                                   'Date Ended:',
                                   'Enforcement:',
                                   'Evaluation:',
                                   'Funding:',
                                   'Legal References:',
                                   'Penalty:',
                                   'Related Documents:',
                                   'Related policies:',
                                   'This record is superseded by:',
                                   'This record supersedes:',
                                   'Funding:',
                                   'Legal References:'])
            
            missing = columns_complete - set(entry.keys())
            
            for c in missing:
                entry[c] = np.nan

            
            
            climate_set.append(entry)



loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
set(optional)
# Out:
# {'Amended:', 'Description:', 'Policy Target:', 'Policy Type:', 'Year:'}

# %%
len(climate_set)
# Out:
# 2790

# %%
climate_set[3]
# Out:
# {'Agency:': 'Tasmania Department of Premier and Cabinet\t\t\t\r\n',
#  'Amended:': nan,
#  'Country:': 'Australia',
#  'Date Amended:': nan,
#  'Date Effective:': '2017',
#  'Date Ended:': nan,
#  'Description:': "Climate Action 21 sets the Tasmanian Government’s agenda for action on climate change through to 2021. It reflects the Tasmanian Government's commitment to addressing the critical issue of climate change and articulates how Tasmania will play its role in the global response to climate change.\nClimate Action 21 is structured into six priorities. Each priority area includes a 2021 vision statement, our actions for 2017 to 2021 and details of initiatives already being progressed by the Tasmanian Government. Climate Action 21 has 37 actions.\nThe Climate Action 21 sets Tasmania on a pathway to reach a target of zero net emissions by 2050. The 2050 Tasmania’s emissions target means that the region’s emissions will be balanced out by our carbon sinks.",
#  'Enforcement:': nan,
#  'Evaluation:': nan,
#  'Funding:': 'AUD 3m (in addition to $400m already invested to support action on climate change)\t\t\t\r\n',
#  'Jurisdiction:': 'State/Regional',
#  'Legal References:': nan,
#  'Name:': "Tasmania's climate change action plan 2017-2021",
#  'Penalty:': nan,
#  'Policy Target:': 'Framework/ Multi-sectoral Policy',
#  'Policy Type:': 'Policy Support>Strategic planning, Information and Education>Information provision, Voluntary Approaches>Public Voluntary Schemes, Economic Instruments>Direct investment',
#  'Policy status:': 'In Force',
#  'Related Documents:': nan,
#  'Related policies:': nan,
#  'Technology Target:': nan,
#  'This record is superseded by:': nan,
#  'This record supersedes:': nan,
#  'URL:': 'http://www.dpac.tas.gov.au/divisions/climatechange/tasmanias_climate_change_action_plan_20172021',
#  'Year:': '2017',
#  'source': 'IEA'}

# %% [markdown]
# ######   IEA/IRENA Global Renewable Energy Policies and Measures Database

# %%
#Scrape each renewable energy policy webpage in db


renew_set = []
optional = list()

async def main():
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:

        loop = asyncio.get_event_loop()
        futures = [
            loop.run_in_executor(
                executor, 
                session.get, 
                link
            )
            for link in renewpage_link_store
        ]
        
        for response in await asyncio.gather(*futures):
            entry = dict()            
            soup_e = BeautifulSoup(response.text, 'html.parser')
            title = soup_e.find(id="banner").get_text()
            table = soup_e.find("tbody").find_all("tr")
            column = [t.find_all("td") for t in table]
            #print(title)
            entry["Name:"] = title
            for t in column:
                if len(t) == 2:
                    header = t[0].get_text()    
                    text = t[1].get_text()
                    if text is "":
                        text = np.nan
                        
#                        print("Undocumented!", header) 
                        optional.append(header)
                        
                    if (header == "Country:" or 
                        header == "Year:" or
                        header == "Policy status:" or
                        header == "Jurisdiction:" or
                        header == "Date Effective:" or
                        header == "Policy Type:" or
                        header == "Policy Target:" or
                        header == "URL:" or
                        header == "Description:" or
                        header == "Technology Target:" or
                        header == 'Agency:'or
                        header == 'Amended:' or
                        header == 'Date Amended:' or
                        header == 'Date Ended:' or
                        header == 'Enforcement:' or
                        header == 'Evaluation:' or
                        header == 'Funding:' or
                        header == 'Legal References:' or
                        header == 'Penalty:' or
                        header == 'Related Documents:' or
                        header == 'Related policies:' or
                        header == 'This record is superseded by:' or
                        header == 'This record supersedes:' or
                        header == 'Funding:'):

                            if entry.get('URL:', 0) != 0 and header == "URL:":
                                pass
                            else:
                                entry[header] = text
                                                
                elif len(t) == 1:
                    text = np.nan
                        
#                    if header not in ["Country:", "Year:", "Policy status:", "Jurisdiction:", "Date Effective:", "Policy Type:", "URL:", "Description:", "Policy Target:", "Technology Target:"]:
#                        print("Undocumented!", header)
#                        optional.append(header)
                        
                    if (header == "Country:" or 
                        header == "Year:" or
                        header == "Policy status:" or
                        header == "Jurisdiction:" or
                        header == "Date Effective:" or
                        header == "Policy Type:" or
                        header == "Policy Target:" or
                        header == "URL:" or
                        header == "Description:" or
                        header == "Technology Target:" or
                        header == 'Agency:'or
                        header == 'Amended:' or
                        header == 'Date Amended:' or
                        header == 'Date Ended:' or
                        header == 'Enforcement:' or
                        header == 'Evaluation:' or
                        header == 'Funding:' or
                        header == 'Legal References:' or
                        header == 'Penalty:' or
                        header == 'Related Documents:' or
                        header == 'Related policies:' or
                        header == 'This record is superseded by:' or
                        header == 'This record supersedes:' or
                        header == 'Funding:'):

                            if entry.get('URL:', 0) !=0 and header == "URL:":
                                pass

                            else:

                                entry[header] = text    
                        
                        
        
            entry["data_source"] = "IEA"
            
            columns_complete = set(["Country:", 
                                   "Year:", 
                                   "Policy status:", 
                                   "Jurisdiction:", 
                                   "Date Effective:", 
                                   "Policy Type:", 
                                   "URL:", 
                                   "Description:", 
                                   "Policy Target:", 
                                   "Technology Target:",
                                   'Agency:',
                                   'Amended:',
                                   'Date Amended:',
                                   'Date Ended:',
                                   'Enforcement:',
                                   'Evaluation:',
                                   'Funding:',
                                   'Legal References:',
                                   'Penalty:',
                                   'Related Documents:',
                                   'Related policies:',
                                   'This record is superseded by:',
                                   'This record supersedes:',
                                   'Funding:',
                                   'Legal References:'])
            
            missing = columns_complete - set(entry.keys())
            
            for c in missing:
                entry[c] = np.nan

            
            
            renew_set.append(entry)



loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
set(optional)
# Out:
# {'Description:', 'Policy Sector:', 'Policy Target:', 'Policy Type:', 'Year:'}

# %%
len(renew_set)
# Out:
# 1494

# %%
renew_set[1]
# Out:
# {'Agency:': 'Ministry of Industry, Energy and Tourism (Minetur)',
#  'Amended:': nan,
#  'Country:': 'Albania',
#  'Date Amended:': nan,
#  'Date Effective:': '2014 (Nov 1st)',
#  'Date Ended:': nan,
#  'Description:': 'Order IET/1882/2014 of 14 October establishes the methodology for calculating the electricity generated by means of non-renewable fuels in STE and hybrid installations (classified in article 2 of RD 413/2014 as b.1.2. and in article 4 of RD 413/2014 as type 2 hybrid installations)/',
#  'Enforcement:': nan,
#  'Evaluation:': nan,
#  'Funding:': nan,
#  'Jurisdiction:': 'National',
#  'Legal References:': 'Order IET/1882/2014 of 14 October; Royal Decree 413/2014',
#  'Name:': 'Order IET/1882/2014 of 14 October. Electricity generated by means of non-renewable fuels in STE  and hybrid installations',
#  'Penalty:': nan,
#  'Policy Target:': 'Solar Thermal>Solar thermal electricity (STE)',
#  'Policy Type:': 'Economic Instruments>Market-based instruments',
#  'Policy status:': 'In Force',
#  'Related Documents:': nan,
#  'Related policies:': nan,
#  'Technology Target:': nan,
#  'This record is superseded by:': nan,
#  'This record supersedes:': nan,
#  'URL:': 'https://www.boe.es/diario_boe/txt.php?id=BOE-A-2014-10475#analisis',
#  'Year:': '2014 (Nov 1st)',
#  'data_source': 'IEA'}

# %% [markdown]
# ###### Energy Efficiency Database

# %%
#Scrape each energy efficiency policy webpage in db
eff_set = []
optional = list()



async def main():
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:

        loop = asyncio.get_event_loop()
        futures = [
            loop.run_in_executor(
                executor, 
                session.get, 
                link
            )
            for link in eff_page_link_store
        ]
        
        for response in await asyncio.gather(*futures):
            entry = dict()            
            soup_e = BeautifulSoup(response.text, 'html.parser')
            title = soup_e.find(id="banner").get_text()
            table = soup_e.find("tbody").find_all("tr")
            column = [t.find_all("td") for t in table]
            #print(title)
            entry["Name:"] = title
            for t in column:
                if len(t) == 2:
                    header = t[0].get_text()    
                    text = t[1].get_text()
                    if text is "":
                        text = np.nan
                        
#                        print("Undocumented!", header) 
                        optional.append(header)
                        
                    if (header == "Country:" or 
                        header == "Year:" or
                        header == "Policy status:" or
                        header == "Jurisdiction:" or
                        header == "Date Effective:" or
                        header == "Policy Type:" or
                        header == "Policy Target:" or
                        header == "URL:" or
                        header == "Description:" or
                        header == "Technology Target:" or
                        header == 'Agency:'or
                        header == 'Amended:' or
                        header == 'Date Amended:' or
                        header == 'Date Ended:' or
                        header == 'Enforcement:' or
                        header == 'Evaluation:' or
                        header == 'Funding:' or
                        header == 'Legal References:' or
                        header == 'Penalty:' or
                        header == 'Related Documents:' or
                        header == 'Related policies:' or
                        header == 'This record is superseded by:' or
                        header == 'This record supersedes:' or
                        header == 'Funding:'):

                            if entry.get('URL:', 0) != 0 and header == "URL:":
                                pass
                            else:
                                entry[header] = text
                                                
                elif len(t) == 1:
                    text = np.nan
                        
#                    if header not in ["Country:", "Year:", "Policy status:", "Jurisdiction:", "Date Effective:", "Policy Type:", "URL:", "Description:", "Policy Target:", "Technology Target:"]:
#                        print("Undocumented!", header)
#                        optional.append(header)
                        
                    if (header == "Country:" or 
                        header == "Year:" or
                        header == "Policy status:" or
                        header == "Jurisdiction:" or
                        header == "Date Effective:" or
                        header == "Policy Type:" or
                        header == "Policy Target:" or
                        header == "URL:" or
                        header == "Description:" or
                        header == "Technology Target:" or
                        header == 'Agency:'or
                        header == 'Amended:' or
                        header == 'Date Amended:' or
                        header == 'Date Ended:' or
                        header == 'Enforcement:' or
                        header == 'Evaluation:' or
                        header == 'Funding:' or
                        header == 'Legal References:' or
                        header == 'Penalty:' or
                        header == 'Related Documents:' or
                        header == 'Related policies:' or
                        header == 'This record is superseded by:' or
                        header == 'This record supersedes:' or
                        header == 'Funding:'):

                            if entry.get('URL:', 0) !=0 and header == "URL:":
                                pass

                            else:

                                entry[header] = text    
                        
                        
        
            entry["data_source"] = "IEA"
            
            columns_complete = set(["Country:", 
                                   "Year:", 
                                   "Policy status:", 
                                   "Jurisdiction:", 
                                   "Date Effective:", 
                                   "Policy Type:", 
                                   "URL:", 
                                   "Description:", 
                                   "Policy Target:", 
                                   "Technology Target:",
                                   'Agency:',
                                   'Amended:',
                                   'Date Amended:',
                                   'Date Ended:',
                                   'Enforcement:',
                                   'Evaluation:',
                                   'Funding:',
                                   'Legal References:',
                                   'Penalty:',
                                   'Related Documents:',
                                   'Related policies:',
                                   'This record is superseded by:',
                                   'This record supersedes:',
                                   'Funding:',
                                   'Legal References:'])
            
            missing = columns_complete - set(entry.keys())
            
            for c in missing:
                entry[c] = np.nan

            
            
            eff_set.append(entry)



loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
len(eff_set)
# Out:
# 1995

# %%
set(optional)
# Out:
# {'Description:', 'Policy Target:', 'Policy Type:', 'Year:'}

# %%
eff_set[8]
# Out:
# {'Agency:': 'Department of Industry',
#  'Amended:': nan,
#  'Country:': 'Australia',
#  'Date Amended:': nan,
#  'Date Effective:': '2012',
#  'Date Ended:': '2014',
#  'Description:': 'The Local Government Energy Efficiency Program (LGEEP) was a non-competitive grant program that will assists local governing authorities (LGAs) install solar and heat pump hot water systems to drive smarter energy use in their buildings and community facilities.\xa0',
#  'Enforcement:': nan,
#  'Evaluation:': nan,
#  'Funding:': 'AUD 6.8 million',
#  'Jurisdiction:': 'National',
#  'Legal References:': nan,
#  'Name:': 'Local Government Energy Efficiency Program (LGEEP)',
#  'Penalty:': nan,
#  'Policy Target:': 'Buildings>Building Type>Non-residential, Residential Appliances>Water heating',
#  'Policy Type:': 'Economic Instruments>Fiscal/financial incentives>Grants and subsidies, Economic Instruments>Direct investment>Funds to sub-national governments',
#  'Policy status:': 'Ended',
#  'Related Documents:': nan,
#  'Related policies:': 'Community Energy Efficiency Program\r\n, Home Energy Saving Scheme (HESS)\n',
#  'Technology Target:': nan,
#  'This record is superseded by:': nan,
#  'This record supersedes:': nan,
#  'URL:': 'http://www.industry.gov.au/Energy/EnergyEfficiency/GrantsFunding/LocalGovernmentEnergyEfficiency/Pages/default.aspx',
#  'Year:': '2012',
#  'data_source': 'IEA'}

# %%
print('climate change policy db:', len(climate_set))
print('renewable energy policy db:', len(renew_set))
print('energy efficiency db:', len(eff_set))

full_set = climate_set + renew_set + eff_set

print('total:', len(full_set))
# Out:
# climate change policy db: 2790
# renewable energy policy db: 1494
# energy efficiency db: 1995
# total: 6279

# %%
iea_db = pd.DataFrame(full_set)

# %%
iea_db
# Out:
#                                                 Agency: Amended:  \
# 0                                                   NaN      NaN
# 1     Ministry of Industry and Energy, National Agen...      NaN
# 2                             Department of Agriculture      NaN
# 3     Tasmania Department of Premier and Cabinet\t\t...      NaN
# 4              Department of the Environment and Energy      NaN
# 5                                 Queensland Government      NaN
# 6              Department of the Environment and Energy      NaN
# 7      Department of the Environment and Energy\r\n\r\n      NaN
# 8              Department of the Environment and Energy      NaN
# 9              Department of the Environment and Energy      NaN
# 10              Department of Foreign Affairs and Trade      NaN
# 11                                Queensland Government      NaN
# 12    Department of the Environment and Energy and Q...      NaN
# 13       Australian Renewable Energy Agency (ARENA)\r\n      NaN
# 14       Australian Renewable Energy Agency (ARENA)\r\n      NaN
# 15                               Clean Energy Regulator      NaN
# 16             Department of the Environment and Energy      NaN
# 17             Department of the Environment and Energy      NaN
# 18       Australian Renewable Energy Agency (ARENA)\r\n      NaN
# 19                    Department of the Environment\r\n      NaN
# 20                               Department of Industry      NaN
# 21                    Department of the Environment\r\n      NaN
# 22                    Department of the Environment\r\n      NaN
# 23                               Department of Industry      NaN
# 24    Department of Innovation, Industry, Science, R...      NaN
# 25                               Department of Industry      NaN
# 26                               Department of Industry      NaN
# 27               Department of Industry and Science\r\n      NaN
# 28    Department of Climate Change and Energy Effici...      NaN
# 29                   Australian Renewable Energy Agency      NaN
# ...                                                 ...      ...
# 6249              Environmental Protection Agency (EPA)      NaN
# 6250  Department of Energy (DOE), Environmental Prot...      NaN
# 6251                    U.S. Department of Energy (DOE)      NaN
# 6252                         Department of Energy (DOE)      NaN
# 6253  Department of Housing and Urban Development (HUD)      NaN
# 6254                    U.S. Department of the Treasury      NaN
# 6255  U.S. Department of Energy (DOE), U.S. Environm...      NaN
# 6256                      US Department of Energy (DOE)      NaN
# 6257                      US Department of Energy (DOE)      NaN
# 6258           US Environmental Protection Agency (EPA)      NaN
# 6259     U.S. Environmental Protection Agency (EPA)\r\n      NaN
# 6260     U.S. Environmental Protection Agency (EPA)\r\n      NaN
# 6261                         Department of Energy (DOE)      NaN
# 6262                      US Department of Energy (DOE)      NaN
# 6263        Department of Housing and Urban Development      NaN
# 6264                      US Department of Energy (DOE)      NaN
# 6265  U.S. Environmental Protection Agency (EPA), U....      NaN
# 6266              Environmental Protection Agency (EPA)      NaN
# 6267                                                NaN      NaN
# 6268                    U.S. Department of Energy (DOE)      NaN
# 6269         US Department of Health and Human Services      NaN
# 6270                                                NaN      NaN
# 6271                      US Department of Energy (DOE)      NaN
# 6272                          U.S. Department of Energy      NaN
# 6273                         Department of Energy (DOE)      NaN
# 6274                         Department of Energy (DOE)      NaN
# 6275                    U.S. Department of Energy (DOE)      NaN
# 6276                         Department of Energy (DOE)      NaN
# 6277  US Department of Transportation (DOT) and Envi...      NaN
# 6278                         Department of Energy (DOE)      NaN
#
#            Country:     Date Amended:     Date Effective:     Date Ended:  \
# 0           Albania               NaN                2015             NaN
# 1           Albania               NaN                2003             NaN
# 2         Australia               NaN     8 December 2011            2014
# 3         Australia               NaN                2017             NaN
# 4         Australia               NaN                2016             NaN
# 5         Australia               NaN                2016             NaN
# 6         Australia               NaN           2015-2016             NaN
# 7         Australia               NaN                2015             NaN
# 8         Australia               NaN                2015             NaN
# 9         Australia               NaN                2015             NaN
# 10        Australia               NaN                2015             NaN
# 11        Australia               NaN                2015             NaN
# 12        Australia               NaN                2015             NaN
# 13        Australia               NaN     2014 (February)             NaN
# 14        Australia               NaN                2014             NaN
# 15        Australia               NaN                2014             NaN
# 16        Australia               NaN                2014             NaN
# 17        Australia               NaN                2014             NaN
# 18        Australia               NaN                2013            2015
# 19        Australia               NaN       2012 (July 1)            2014
# 20        Australia               NaN       2012 (2 July)             NaN
# 21        Australia               NaN       2012 (1 July)  2014 (30 June)
# 22        Australia               NaN               2012             2014
# 23        Australia               NaN                2012  2017 (30 June)
# 24        Australia               NaN                2012             NaN
# 25        Australia               NaN                2012            2014
# 26        Australia               NaN                2012             NaN
# 27        Australia               NaN                2012             NaN
# 28        Australia               NaN                2012             NaN
# 29        Australia  2015 (Sept 24th)     2011 (Mai 10th)             NaN
# ...             ...               ...                 ...             ...
# 6249  United States               NaN                1997             NaN
# 6250  United States               NaN                1996             NaN
# 6251  United States               NaN                1996             NaN
# 6252  United States               NaN                1996             NaN
# 6253  United States               NaN                1996             NaN
# 6254  United States               NaN                1996             NaN
# 6255  United States               NaN                1995             NaN
# 6256  United States               NaN                1994             NaN
# 6257  United States               NaN                1993             NaN
# 6258  United States               NaN                1993             NaN
# 6259  United States               NaN                1992             NaN
# 6260  United States               NaN                1992             NaN
# 6261  United States               NaN                1992             NaN
# 6262  United States        2005, 2007                1992             NaN
# 6263  United States               NaN                1992             NaN
# 6264  United States               NaN                1992             NaN
# 6265  United States               NaN                1992             NaN
# 6266  United States               NaN                1992             NaN
# 6267  United States               NaN                1991             NaN
# 6268  United States               NaN                1988             NaN
# 6269  United States               NaN  1982; amended 2005             NaN
# 6270  United States               NaN                1981             NaN
# 6271  United States               NaN                1978             NaN
# 6272  United States               NaN                1978             NaN
# 6273  United States               NaN                1976             NaN
# 6274  United States               NaN                1976             NaN
# 6275  United States               NaN                1976             NaN
# 6276  United States               NaN                1975             NaN
# 6277  United States               NaN                1975             NaN
# 6278  United States               NaN                1970             NaN
#
#                                            Description: Enforcement:  \
# 0     The 21st session of the Conference of the Part...          NaN
# 1     The main goal of the Albanian National Strateg...          NaN
# 2     The Carbon Farming Initiative (CFI) was a volu...          NaN
# 3     Climate Action 21 sets the Tasmanian Governmen...          NaN
# 4     The $5 million Solar Communities program will ...          NaN
# 5     The Queensland Government, in partnership with...          NaN
# 6     Develop a formal government strategy and imple...          NaN
# 7     The Clean Energy Finance Corporation (CEFC) wa...          NaN
# 8     In line with the Government's commitment to re...          NaN
# 9     Australia’s post-2020 emission reduction targe...          NaN
# 10    The 21st session of the Conference of the Part...          NaN
# 11    The Queensland Government is investing $3 mill...          NaN
# 12    The Reef 2050 Plan was released by the Austral...          NaN
# 13    The SHARE initiative is the first stage in ARE...          NaN
# 14     \nThe Research and Development (R&D) Programm...          NaN
# 15    The objective of the Emissions Reduction Fund ...          NaN
# 16    The Australian Government will work with the c...          NaN
# 17    YourEnergySavings.gov.au is the place to go to...          NaN
# 18    The Regional Australia’s Renewables (RAR) init...          NaN
# 19    The previous Australian government introduced ...          NaN
# 20    The objective of the Coal Mining Abatement Tec...          NaN
# 21    The Jobs and Competitiveness Program provided ...          NaN
# 22    The previous government's Clean Energy Future ...          NaN
# 23    The Coal Sector Jobs Package (CSJP) provides t...          NaN
# 24    The AUD800 million Clean Technology Investment...          NaN
# 25    The Local Government Energy Efficiency Program...          NaN
# 26    The Clean Technology Innovation Programme prov...          NaN
# 27    The Industrial Energy Efficiency Data Analysis...          NaN
# 28    The Australian Government announced its intent...          NaN
# 29    ARENA’s up to $60 million Renewable Energy Ven...          NaN
# ...                                                 ...          ...
# 6249  Heat islands are a phenomena where urban and s...          NaN
# 6250  Part of the ENERGY STAR program, this initiati...          NaN
# 6251  The State Energy Program (SEP) provides grants...          NaN
# 6252  The directory provides information on building...          NaN
# 6253  Native American Housing Block Grants provide f...          NaN
# 6254  The U.S. Treasury Departments Residential Ener...          NaN
# 6255  ENERGY STAR Certified New Homes meet strict gu...          NaN
# 6256  The Federal Utility Partnership Working Group ...          NaN
# 6257  Clean Cities is a government-industry partners...          NaN
# 6258  The Environmentally Preferable Purchasing (EPP...          NaN
# 6259  ENERGY STAR for Industry is a voluntary U.S. E...          NaN
# 6260  Energy Star Commercial Buildings is a voluntar...          NaN
# 6261  The Building Energy Codes Program (BECP) missi...          NaN
# 6262  Under the Energy Policy Act of 1992 State and ...          NaN
# 6263  Energy Efficient Mortgages (EEMs) can be used ...          NaN
# 6264  The Vehicle Technologies Office aims to develo...          NaN
# 6265  ENERGY STAR Products must meet certain minimum...          NaN
# 6266  Energy Savings Performance Contracts (ESPCs) w...          NaN
# 6267  The National Industrial Competitiveness throug...          NaN
# 6268  This Department of Energy (DOE)-managed progra...          NaN
# 6269  LIHEAP is a Federally funded block grant progr...          NaN
# 6270  The Low Income Home Energy Assistance Program ...          NaN
# 6271  PURPA created a market for power from non-util...          NaN
# 6272  The Department of Energys Federal Energy Manag...          NaN
# 6273  The Weatherization Assistance Program (WAP) en...          NaN
# 6274  The Weatherization and Intergovernmental Progr...          NaN
# 6275  Industrial Assessment Centers (IACs) provide e...          NaN
# 6276  The Advanced Manufacturing Office [formerly In...          NaN
# 6277  Corporate Average Fuel Economy (CAFE) is the r...          NaN
# 6278  BestPractices, under the Industrial Technologi...          NaN
#
#                                             Evaluation:  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 6249                                                NaN
# 6250                                                NaN
# 6251                                                NaN
# 6252                                                NaN
# 6253                                                NaN
# 6254                                                NaN
# 6255                                                NaN
# 6256                                                NaN
# 6257                                                NaN
# 6258                                                NaN
# 6259                                                NaN
# 6260                                                NaN
# 6261                                                NaN
# 6262                                                NaN
# 6263                                                NaN
# 6264                                                NaN
# 6265  www.energystar.gov/ia/news/downloads/annual_re...
# 6266                                                NaN
# 6267                                                NaN
# 6268                                                NaN
# 6269                                                NaN
# 6270                                                NaN
# 6271                                                NaN
# 6272                                                NaN
# 6273                                                NaN
# 6274                                                NaN
# 6275                                                NaN
# 6276                                                NaN
# 6277                                                NaN
# 6278                                                NaN
#
#                                                Funding:     ...       \
# 0                                                   NaN     ...
# 1                                                   NaN     ...
# 2                                                   NaN     ...
# 3     AUD 3m (in addition to $400m already invested ...     ...
# 4                                         AUD$5 million     ...
# 5                                        AUD$12 million     ...
# 6                                                   NaN     ...
# 7     $2 billion AUD per annum for 5 years commencin...     ...
# 8                                                   NaN     ...
# 9                                                   NaN     ...
# 10                                                  NaN     ...
# 11                                        AUD 3 million     ...
# 12                                                  NaN     ...
# 13                                                  NaN     ...
# 14    Announced funding of up to $300 million over t...     ...
# 15                                     AUD 2.55 billion     ...
# 16                                       AUD$43 million     ...
# 17                                    Internally funded     ...
# 18    Up to $400 million, shared with the Industry R...     ...
# 19                                                  NaN     ...
# 20                                     AUD 36.7 million     ...
# 21                                      AUD 8.6 billion     ...
# 22                                                  NaN     ...
# 23    AUD 448.7 million. No funding remains after 1 ...     ...
# 24                         AUD 800 million over 7 years     ...
# 25                                      AUD 6.8 million     ...
# 26                      AUD 200 million over five years     ...
# 27                                AUD 950 000\t\t\t\r\n     ...
# 28                                                  NaN     ...
# 29    AUD 120 million (Government AUD 60 million; pr...     ...
# ...                                                 ...     ...
# 6249                                                NaN     ...
# 6250                                                NaN     ...
# 6251                                                NaN     ...
# 6252                                                NaN     ...
# 6253  USD255 million.  Funds shall remain available ...     ...
# 6254                                                NaN     ...
# 6255                                                NaN     ...
# 6256                                                NaN     ...
# 6257                                                NaN     ...
# 6258                                                NaN     ...
# 6259                                                NaN     ...
# 6260                                                NaN     ...
# 6261                                                NaN     ...
# 6262                                                NaN     ...
# 6263                                                NaN     ...
# 6264                                                NaN     ...
# 6265                                                NaN     ...
# 6266                                                NaN     ...
# 6267                                                NaN     ...
# 6268                USD 20 million requested for FY2009     ...
# 6269  2009 Appropriation: Block Grant: USD 4.5 billi...     ...
# 6270                                                NaN     ...
# 6271                                                NaN     ...
# 6272                                                NaN     ...
# 6273                         USD 65 million (FY 12)\r\n     ...
# 6274                                                NaN     ...
# 6275                      USD 4.4 million (FY 2012)\r\n     ...
# 6276        Total ITP budget: $62.1M requested for FY09     ...
# 6277                     USD 7.9 million in FY2013 \r\n     ...
# 6278                                                NaN     ...
#
#                                            Policy Type: Policy status:  \
# 0                     Policy Support>Strategic planning       In Force
# 1                     Policy Support>Strategic planning       In Force
# 2     Economic Instruments>Market-based instruments>...     Superseded
# 3     Policy Support>Strategic planning, Information...       In Force
# 4     Economic Instruments>Fiscal/financial incentiv...       In Force
# 5     Economic Instruments>Fiscal/financial incentiv...       In Force
# 6     Regulatory Instruments>Codes and standards, Re...          Ended
# 7     Economic Instruments>Fiscal/financial incentiv...       In Force
# 8            Regulatory Instruments>Codes and standards       In Force
# 9                     Policy Support>Strategic planning       In Force
# 10                    Policy Support>Strategic planning       In Force
# 11                            Information and Education       In Force
# 12                    Policy Support>Strategic planning       In Force
# 13    Research, Development and Deployment (RD&D;), ...     Superseded
# 14         Research, Development and Deployment (RD&D;)       In Force
# 15    Policy Support, Economic Instruments>Market-ba...       In Force
# 16    Economic Instruments>Fiscal/financial incentiv...       In Force
# 17      Information and Education>Information provision       In Force
# 18         Research, Development and Deployment (RD&D;)     Superseded
# 19    Economic Instruments>Fiscal/financial incentiv...          Ended
# 20    Economic Instruments>Fiscal/financial incentiv...          Ended
# 21    Economic Instruments>Direct investment, Econom...          Ended
# 22    Research, Development and Deployment (RD&D;), ...          Ended
# 23               Economic Instruments>Direct investment          Ended
# 24    Economic Instruments>Fiscal/financial incentiv...          Ended
# 25    Economic Instruments>Fiscal/financial incentiv...          Ended
# 26    Research, Development and Deployment (RD&D;)>R...          Ended
# 27                                       Policy Support          Ended
# 28    Economic Instruments>Market-based instruments>...     Superseded
# 29    Voluntary Approaches>Negotiated Agreements (Pu...       In Force
# ...                                                 ...            ...
# 6249  Voluntary Approaches>Negotiated Agreements (Pu...          Ended
# 6250  Information and Education>Information provisio...     Superseded
# 6251  Economic Instruments>Fiscal/financial incentiv...       In Force
# 6252  Information and Education>Information provisio...          Ended
# 6253  Economic Instruments>Fiscal/financial incentiv...          Ended
# 6254  Economic Instruments>Fiscal/financial incentiv...       In Force
# 6255  Voluntary Approaches, Information and Educatio...       In Force
# 6256    Information and Education>Information provision       In Force
# 6257  Voluntary Approaches>Negotiated Agreements (Pu...       In Force
# 6258  Economic Instruments>Direct investment>Procure...       In Force
# 6259  Voluntary Approaches>Negotiated Agreements (Pu...       In Force
# 6260  Voluntary Approaches>Negotiated Agreements (Pu...       In Force
# 6261  Regulatory Instruments, Information and Educat...       In Force
# 6262  Economic Instruments>Direct investment>Procure...     Superseded
# 6263  Economic Instruments>Fiscal/financial incentiv...       In Force
# 6264  Research, Development and Deployment (RD&D;)>R...       In Force
# 6265  Voluntary Approaches>Negotiated Agreements (Pu...       In Force
# 6266  Economic Instruments>Direct investment>Procure...       In Force
# 6267  Economic Instruments>Fiscal/financial incentiv...          Ended
# 6268         Regulatory Instruments>Codes and standards       In Force
# 6269  Economic Instruments>Fiscal/financial incentiv...       In Force
# 6270  Economic Instruments>Direct investment>Funds t...     Superseded
# 6271  Economic Instruments, Economic Instruments>Mar...       In Force
# 6272  Economic Instruments>Direct investment>Procure...       In Force
# 6273  Economic Instruments>Fiscal/financial incentiv...       In Force
# 6274  Research, Development and Deployment (RD&D;)>R...       In Force
# 6275  Information and Education>Advice/Aid in Implem...       In Force
# 6276  Research, Development and Deployment (RD&D;)>R...     Superseded
# 6277  Regulatory Instruments>Codes and standards, Re...       In Force
# 6278  Information and Education>Information provisio...     Superseded
#
#      Related Documents:                                  Related policies:  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN  Carbon Farming Futures\r\n, Carbon Farming Ski...
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# 5                   NaN                                                NaN
# 6                   NaN       Australian Renewable Energy Agency (ARENA)\n
# 7                   NaN       Australian Renewable Energy Agency (ARENA)\n
# 8                   NaN                                                NaN
# 9                   NaN  Nationally Determined Contribution (NDC) to th...
# 10                  NaN                                                NaN
# 11                  NaN                                                NaN
# 12                  NaN                                                NaN
# 13                  NaN                          Clean Energy Initiative\n
# 14                  NaN                          Clean Energy Initiative\n
# 15                  NaN                                                NaN
# 16                  NaN                                                NaN
# 17                  NaN                                                NaN
# 18                  NaN                          Clean Energy Initiative\n
# 19                  NaN  Jobs and Competitiveness Program\r\n, Clean En...
# 20                  NaN                                                NaN
# 21                  NaN                         Carbon Pricing Mechanism\n
# 22                  NaN  Clean Energy Finance Corporation (CEFC)\r\n, C...
# 23                  NaN                                                NaN
# 24                  NaN                                                NaN
# 25                  NaN  Community Energy Efficiency Program\r\n, Home ...
# 26                  NaN         Clean Technology Focus for Supply Chains\n
# 27                  NaN        Energy Efficiency Opportunities Programme\n
# 28                  NaN                                                NaN
# 29                  NaN          Clean Energy Finance Corporation (CEFC)\n
# ...                 ...                                                ...
# 6249                NaN                                                NaN
# 6250                NaN                                                NaN
# 6251                NaN                                                NaN
# 6252                NaN                                                NaN
# 6253                NaN                                                NaN
# 6254                NaN                                                NaN
# 6255                NaN                                                NaN
# 6256                NaN                                                NaN
# 6257                NaN                                                NaN
# 6258                NaN                                                NaN
# 6259                NaN                                                NaN
# 6260                NaN                                                NaN
# 6261                NaN                                                NaN
# 6262                NaN                                                NaN
# 6263                NaN                                                NaN
# 6264                NaN                                                NaN
# 6265                NaN                                                NaN
# 6266                NaN                                                NaN
# 6267                NaN                                                NaN
# 6268                NaN                                                NaN
# 6269                NaN                                                NaN
# 6270                NaN                                                NaN
# 6271                NaN                                                NaN
# 6272                NaN                                                NaN
# 6273                NaN                                                NaN
# 6274                NaN                                                NaN
# 6275                NaN                                                NaN
# 6276                NaN                                                NaN
# 6277                NaN                                                NaN
# 6278                NaN                                                NaN
#
#      Technology Target:                   This record is superseded by:  \
# 0                   NaN                                             NaN
# 1                   NaN                                             NaN
# 2                   NaN                      Emissions Reduction Fund\n
# 3                   NaN                                             NaN
# 4                   NaN                                             NaN
# 5                   NaN                                             NaN
# 6                   NaN                                             NaN
# 7                   NaN                                             NaN
# 8                   NaN                                             NaN
# 9                   NaN                                             NaN
# 10                  NaN                                             NaN
# 11                  NaN                                             NaN
# 12                  NaN                                             NaN
# 13                  NaN              Advancing Renewables Programme\n\n
# 14                  NaN                                             NaN
# 15                  NaN                                             NaN
# 16                  NaN                                             NaN
# 17                  NaN                                             NaN
# 18                  NaN                Advancing Renewables Programme\n
# 19                  NaN                                             NaN
# 20                  NaN                                             NaN
# 21                  NaN                                             NaN
# 22                  NaN                                             NaN
# 23                  NaN                                             NaN
# 24                  NaN                                             NaN
# 25                  NaN                                             NaN
# 26                  NaN                                             NaN
# 27                  NaN                                             NaN
# 28                  NaN                      Carbon Pricing Mechanism\n
# 29                  NaN                                             NaN
# ...                 ...                                             ...
# 6249                NaN                                             NaN
# 6250                NaN         Home Performance with ENERGY STAR\r\n\n
# 6251                NaN                                             NaN
# 6252                NaN                                             NaN
# 6253                NaN                                             NaN
# 6254                NaN                                             NaN
# 6255                NaN                                             NaN
# 6256                NaN      Federal Energy Management Program (FEMP)\n
# 6257                NaN                                             NaN
# 6258                NaN                                             NaN
# 6259                NaN                                             NaN
# 6260                NaN                                             NaN
# 6261                NaN                                             NaN
# 6262                NaN                                             NaN
# 6263                NaN                                             NaN
# 6264                NaN                                             NaN
# 6265                NaN                                             NaN
# 6266                NaN      Federal Energy Management Program (FEMP)\n
# 6267                NaN                                             NaN
# 6268                NaN                                             NaN
# 6269                NaN                                             NaN
# 6270                NaN       Weatherization Assistance Program (WAP)\n
# 6271                NaN  Energy Independence and Security Act of 2007\n
# 6272                NaN                                             NaN
# 6273                NaN                                             NaN
# 6274                NaN       Weatherization Assistance Program (WAP)\n
# 6275                NaN                                             NaN
# 6276                NaN                                             NaN
# 6277                NaN                                             NaN
# 6278                NaN                                             NaN
#
#                                 This record supersedes:  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14    Supporting High Value Australian Renewable Ene...
# 15                                                  NaN
# 16                                                  NaN
# 17               LivingGreener.gov.au - Online portal\n
# 18    Supporting High Value Australian Renewable Ene...
# 19                Australian Emissions Trading Scheme\n
# 20                                                  NaN
# 21                                                  NaN
# 22                            Clean Energy Initiative\n
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 6249                                                NaN
# 6250                                                NaN
# 6251                                                NaN
# 6252                                                NaN
# 6253                                                NaN
# 6254                                                NaN
# 6255                                                NaN
# 6256                                                NaN
# 6257                                                NaN
# 6258                                                NaN
# 6259                                                NaN
# 6260                                                NaN
# 6261  Energy Conservation Codes for Public and Assis...
# 6262                                                NaN
# 6263                                                NaN
# 6264                                                NaN
# 6265                                                NaN
# 6266                                                NaN
# 6267                                                NaN
# 6268                                                NaN
# 6269                                                NaN
# 6270                                                NaN
# 6271                                                NaN
# 6272  Federal Utility Partnership Working Group (FUP...
# 6273               Technical Assistance Program (TAP)\n
# 6274                                                NaN
# 6275                                                NaN
# 6276                                                NaN
# 6277  Corporate Average Fuel Economy (CAFE): Light T...
# 6278                                                NaN
#
#                                                    URL:               Year:  \
# 0     http://www4.unfccc.int/ndcregistry/PublishedDo...                2015
# 1     http://unfccc.int/files/meetings/seminar/appli...                2003
# 2     http://www.agriculture.gov.au/climatechange/ca...     8 December 2011
# 3     http://www.dpac.tas.gov.au/divisions/climatech...                2017
# 4     http://www.environment.gov.au/climate-change/r...                2016
# 5     https://www.qld.gov.au/environment/climate/ada...                2016
# 6                       http://www.environment.gov.au             2015-2016
# 7              http://www.cleanenergyfinancecorp.com.au                2015
# 8                         http://www.environment.gov.au                2015
# 9     https://www.environment.gov.au/climate-change/...                2015
# 10    http://dfat.gov.au/international-relations/the...                2015
# 11    https://www.qld.gov.au/environment/climate/ada...                2015
# 12    http://www.environment.gov.au/marine/gbr/long-...                2015
# 13    http://arena.gov.au/initiatives-and-programs/s...     2014 (February)
# 14    https://arena.gov.au/programs/research-and-dev...                2014
# 15    http://www.environment.gov.au/climate-change/e...                2014
# 16      http://www.nrm.gov.au/national/20-million-trees                2014
# 17                  http://www.YourEnergySavings.gov.au                2014
# 18    http://arena.gov.au/initiatives-and-programs/r...                2013
# 19    http://www.environment.gov.au/climate-change/r...       2012 (July 1)
# 20                                                  NaN       2012 (2 July)
# 21    http://www.cleanenergyregulator.gov.au/Infohub...       2012 (1 July)
# 22                http://www.cleanenergyfuture.gov.au/                2012
# 23                                                  NaN                2012
# 24    http://www.innovation.gov.au/INDUSTRY/CLEANENE...                2012
# 25    http://www.industry.gov.au/Energy/EnergyEffici...                2012
# 26    http://www.business.gov.au/grants-and-assistan...                2012
# 27    http://www.climateworksaustralia.org/project/c...                2012
# 28    http://www.cleanenergyfuture.gov.au/australia-...                2012
# 29            http://www.cleanenergyfinancecorp.com.au/     2011 (Mai 10th)
# ...                                                 ...                 ...
# 6249                    http://www.epa.gov/heatislands/                1997
# 6250                                http://hes.lbl.gov/                1996
# 6251   http://energy.gov/eere/wipo/state-energy-program                1996
# 6252  http://apps1.eere.energy.gov/buildings/tools_d...                1996
# 6253  http://www.hud.gov/offices/pih/ih/grants/ihbg.cfm                1996
# 6254  http://programs.dsireusa.org/system/program/de...                1996
# 6255  http://www.energystar.gov/index.cfm?c=new_home...                1995
# 6256  http://energy.gov/eere/femp/federal-utility-pa...                1994
# 6257                    https://cleancities.energy.gov/                1993
# 6258                            http://www.epa.gov/epp/                1993
# 6259  http://www.energystar.gov/buildings/facility-o...                1992
# 6260        http://www.energystar.gov/buildings/?s=mega                1992
# 6261                         http://www.energycodes.gov                1992
# 6262  http://www1.eere.energy.gov/vehiclesandfuels/e...                1992
# 6263  http://www.hud.gov/offices/hsg/sfh/eem/eemhome...                1992
# 6264  http://energy.gov/eere/vehicles/vehicle-techno...                1992
# 6265  http://www.energystar.gov/index.cfm?fuseaction...                1992
# 6266  http://energy.gov/eere/femp/energy-savings-per...                1992
# 6267                                                NaN                1991
# 6268  http://www1.eere.energy.gov/buildings/applianc...                1988
# 6269        http://www.acf.hhs.gov/programs/ocs/liheap/  1982; amended 2005
# 6270  https://www.acf.hhs.gov/ocs/resource/liheap-fa...                1981
# 6271                 http://www.oe.energy.gov/purpa.htm                1978
# 6272                   http://www.eere.energy.gov/femp/                1978
# 6273  http://energy.gov/eere/wipo/weatherization-ass...                1976
# 6274  http://energy.gov/eere/wipo/weatherization-and...                1976
# 6275  http://energy.gov/eere/amo/industrial-assessme...                1976
# 6276  http://www.eere.energy.gov/industry/technologi...                1975
# 6277                  http://www.nhtsa.gov/fuel-economy                1975
# 6278  http://www.eere.energy.gov/industry/bestpracti...                1970
#
#       data_source
# 0             IEA
# 1             IEA
# 2             IEA
# 3             IEA
# 4             IEA
# 5             IEA
# 6             IEA
# 7             IEA
# 8             IEA
# 9             IEA
# 10            IEA
# 11            IEA
# 12            IEA
# 13            IEA
# 14            IEA
# 15            IEA
# 16            IEA
# 17            IEA
# 18            IEA
# 19            IEA
# 20            IEA
# 21            IEA
# 22            IEA
# 23            IEA
# 24            IEA
# 25            IEA
# 26            IEA
# 27            IEA
# 28            IEA
# 29            IEA
# ...           ...
# 6249          IEA
# 6250          IEA
# 6251          IEA
# 6252          IEA
# 6253          IEA
# 6254          IEA
# 6255          IEA
# 6256          IEA
# 6257          IEA
# 6258          IEA
# 6259          IEA
# 6260          IEA
# 6261          IEA
# 6262          IEA
# 6263          IEA
# 6264          IEA
# 6265          IEA
# 6266          IEA
# 6267          IEA
# 6268          IEA
# 6269          IEA
# 6270          IEA
# 6271          IEA
# 6272          IEA
# 6273          IEA
# 6274          IEA
# 6275          IEA
# 6276          IEA
# 6277          IEA
# 6278          IEA
#
# [6279 rows x 25 columns]

# %%
list(iea_db.columns)
# Out:
# ['Agency:',
#  'Amended:',
#  'Country:',
#  'Date Amended:',
#  'Date Effective:',
#  'Date Ended:',
#  'Description:',
#  'Enforcement:',
#  'Evaluation:',
#  'Funding:',
#  'Jurisdiction:',
#  'Legal References:',
#  'Name:',
#  'Penalty:',
#  'Policy Target:',
#  'Policy Type:',
#  'Policy status:',
#  'Related Documents:',
#  'Related policies:',
#  'Technology Target:',
#  'This record is superseded by:',
#  'This record supersedes:',
#  'URL:',
#  'Year:',
#  'data_source']

# %%
iea_db.rename(columns={'Name:': 'name', 
                       'Country:':'country',
                       'Agency:' : 'agency',
                         'Date Effective:': 'policy_implementation_period_start_year',
                         'Date Ended:': 'policy_implementation_period_end_year',
                         'Description:': 'description',
                         'Evaluation:' : 'impact_evaluation',
                         'Funding:' : 'policy_financing_quantity',
                         'Jurisdiction:': 'jurisdiction',
                         'Policy Target:': 'policy_target',
                         'Policy Type:' : 'policy_type',
                         'Policy status:' : 'policy_status',
                         'Related Documents:' : 'related_documents',
                         'URL:' : 'link',
                         'Year:' : 'policy_written_year' }, inplace=True)

list(iea_db.columns)
# Out:
# ['agency',
#  'Amended:',
#  'country',
#  'Date Amended:',
#  'policy_implementation_period_start_year',
#  'policy_implementation_period_end_year',
#  'description',
#  'Enforcement:',
#  'impact_evaluation',
#  'policy_financing_quantity',
#  'jurisdiction',
#  'Legal References:',
#  'name',
#  'Penalty:',
#  'policy_target',
#  'policy_type',
#  'policy_status',
#  'related_documents',
#  'Related policies:',
#  'Technology Target:',
#  'This record is superseded by:',
#  'This record supersedes:',
#  'link',
#  'policy_written_year',
#  'data_source']

# %%
#combine 'Technology Target:' + 'Policy Target:'

iea_db['policy_target'] = iea_db['policy_target'] + iea_db['Technology Target:']

# %%
#drop other columns

iea_db = iea_db.drop(['Legal References:', 'Amended:', 'Date Amended:', 'Enforcement:', 'Penalty:', 'Related policies:', 'This record is superseded by:', 'This record supersedes:', 'Technology Target:'], axis=1)

list(iea_db.columns)
# Out:
# ['agency',
#  'country',
#  'policy_implementation_period_start_year',
#  'policy_implementation_period_end_year',
#  'description',
#  'impact_evaluation',
#  'policy_financing_quantity',
#  'jurisdiction',
#  'name',
#  'policy_target',
#  'policy_type',
#  'policy_status',
#  'related_documents',
#  'link',
#  'policy_written_year',
#  'data_source']

# %%
dropped_columns = ['Legal References:', 'Amended:', 'Date Amended:', 'Enforcement:', 'Penalty:', 'Related policies:', 'This record is superseded by:', 'This record supersedes:', 'Technology Target:']


print("Dropped columns:", ", ".join(dropped_columns))
# Out:
# Dropped columns: Legal References:, Amended:, Date Amended:, Enforcement:, Penalty:, Related policies:, This record is superseded by:, This record supersedes:, Technology Target:

# %%
# add the rest

iea_db['world_region'] = np.nan
iea_db['country_region'] = np.nan
iea_db['city'] = np.nan
iea_db['ghgs_affected'] = np.nan
iea_db['related_to_eu_policy_boolean'] = np.nan
iea_db['related_to_eu_policy'] = np.nan
iea_db['impact_on_eu_ets_esd_or_lulucf_emissions'] = np.nan
iea_db['total_ghg_emissions_reductions_in_2020'] = np.nan
iea_db['total_ghg_emissions_reductions_in_2030'] = np.nan
iea_db['related_to_neeap_policy_boolean'] = np.nan
iea_db['related_to_neeap_policy'] = np.nan
iea_db['policy_financing_period_start'] = np.nan
iea_db['policy_financing_period_end'] = np.nan
iea_db['percent_private_funded'] = np.nan

list(iea_db.columns)
len(list(iea_db.columns))
# Out:
# 30

# %%
#to csv
iea_db.to_csv(path_or_buf='data/iea_db.csv', index=False)

# %%
iea = pd.read_csv('data/iea_db.csv')
iea.columns
# Out:
# Index(['agency', 'country', 'policy_implementation_period_start_year',
#        'policy_implementation_period_end_year', 'description',
#        'impact_evaluation', 'policy_financing_quantity', 'jurisdiction',
#        'name', 'policy_target', 'policy_type', 'policy_status',
#        'related_documents', 'link', 'policy_written_year', 'data_source',
#        'world_region', 'country_region', 'city', 'ghgs_affected',
#        'related_to_eu_policy_boolean', 'related_to_eu_policy',
#        'impact_on_eu_ets_esd_or_lulucf_emissions',
#        'total_ghg_emissions_reductions_in_2020',
#        'total_ghg_emissions_reductions_in_2030',
#        'related_to_neeap_policy_boolean', 'related_to_neeap_policy',
#        'policy_financing_period_start', 'policy_financing_period_end',
#        'percent_private_funded'],
#       dtype='object')

# %%
iea_countries = iea['country'].tolist()
set(iea_countries)
# Out:
# {'Albania',
#  'Algeria',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Canada',
#  'China',
#  'Croatia',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'European Union',
#  'Finland',
#  'France',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Korea',
#  'Latvia',
#  'Luxembourg',
#  'Malaysia',
#  'Mauritius',
#  'Mexico',
#  'Mongolia',
#  'Montenegro',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Oman',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'South Africa',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'United Kingdom',
#  'United States'}

# %%
iea_slice = iea[['country', 'policy_implementation_period_start_year']]

# %% [markdown]
# ## European Environment Agency Climate Change Mitigation Policies and Measures

# %% [markdown]
# ### How this dataset was originated:
#
# This database contains a number of policies and measures (PaM) implemented, adopted or planned by European countries to reduce greenhouse gas (GHG) emissions. These PaMs have been reported by Member States under the European Union (EU) Monitoring Mechanism Regulation (MMR) as recently 2017 and 2018. Member States report main characteristics of the PaMs, such as their description, objective, type, status, sectors affected, related Union Policy, entities responsible for their implementation, implementation period, etc under the reporting obligations for Greenhouse gas Monitoring Mechanism Regulation (MMR). To facilitate reporting by Member States, the EEA uses an online reporting questionnaire available via ReportNet and ‘Guidelines for reporting on policies and measures by Member States under Regulation (EU) No 525/2013 (EU Monitoring Mechanism Regulation)’<sup>1</sup>
#
# ___
# <sup>1</sup>"EEA database on climate change mitigation policies and measures in Europe", European Environment Agency. Retrieved September 10, 2019 (http://pam.apps.eea.europa.eu/?source=%7B%22query%22%3A%7B%22match_all%22%3A%7B%7D%7D%2C%22display_type%22%3A%22tabular%22%2C%22sort%22%3A%5B%7B%22Country%22%3A%7B%22order%22%3A%22asc%22%7D%7D%2C%7B%22ID_of_policy_or_measure%22%3A%7B%22order%22%3A%22asc%22%7D%7D%5D%2C%22highlight%22%3A%7B%22fields%22%3A%7B%22*%22%3A%7B%7D%7D%7D%7D)

# %% [markdown]
# ### How we got this data:
#
# To retrieve this data we downloaded a csv file of the entire database and used pandas to convert it to a pandas dataframe, selected relevant features for our dataset and exported them to a new csv for seeding our database.

# %%
#load in data from csv
eea_db = pd.read_csv('data/source/eea.csv', encoding = "utf-8")
print(eea_db.shape)
eea_db.head()
# Out:
# (1595, 71)
#    Country  ID of policy or measure  \
# 0  Austria                        1
# 1  Austria                        2
# 2  Austria                        3
# 3  Austria                        4
# 4  Austria                        5
#
#                                         Report ID ES  \
# 0  http://cdr.eionet.europa.eu/Converters/run_con...
# 1  http://cdr.eionet.europa.eu/Converters/run_con...
# 2  http://cdr.eionet.europa.eu/Converters/run_con...
# 3  http://cdr.eionet.europa.eu/Converters/run_con...
# 4  http://cdr.eionet.europa.eu/Converters/run_con...
#
#                            Name of policy or measure  \
# 0                   EU Emission Trading Scheme (ETS)
# 1              Domestic Environmental Support Scheme
# 2          Austrian Climate and Energy Fund (KLI.EN)
# 3  Increase the share of renewable energy in ener...
# 4  Increase energy efficiency in energy and manuf...
#
#   Single policy or measure, or group of measures  Report_ID  \
# 0                                         Single       2909
# 1                                         Single       2909
# 2                                         Single       2909
# 3                                         Single       2909
# 4                                         Single       2909
#
#   Policies or measures included in the group       Type of policy instrument  \
# 0                                 Single PaM            Economic, Regulatory
# 1                                 Single PaM                        Economic
# 2                                 Single PaM              Economic, Research
# 3                                 Single PaM            Economic, Regulatory
# 4                                 Single PaM  Economic, Planning, Regulatory
#
#   Status of implementation Policy impacting EU ETS, ESD or LULUCF emissions  \
# 0              Implemented                                           EU ETS
# 1              Implemented                                      EU ETS, ESD
# 2              Implemented                                      EU ETS, ESD
# 3              Implemented                                      EU ETS, ESD
# 4              Implemented                                      EU ETS, ESD
#
#                  ...                 Price reference year (realised costs)  \
# 0                ...                                                   NaN
# 1                ...                                                   NaN
# 2                ...                                                   NaN
# 3                ...                                                   NaN
# 4                ...                                                   NaN
#
#   Realised benefits (EUR per tonne CO2eq reduced/ sequestered)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Realised absolute benefit per year (EUR)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Realised net costs (EUR per tonne CO2eq reduced/ sequestered)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Realised net cost per year (EUR) Description of realised cost estimates  \
# 0                              NaN                                    NaN
# 1                              NaN                                    NaN
# 2                              NaN                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
#
#   Reference for realised costs and benefits  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Web link for realised costs and benefits  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Projected net cost per year (EUR).1 Realised net cost per year (EUR).1
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
#
# [5 rows x 71 columns]

# %%
list(eea_db.columns)
# Out:
# ['Country',
#  'ID of policy or measure',
#  'Report ID ES',
#  'Name of policy or measure',
#  'Single policy or measure, or group of measures',
#  'Report_ID',
#  'Policies or measures included in the group',
#  'Type of policy instrument',
#  'Status of implementation',
#  'Policy impacting EU ETS, ESD or LULUCF emissions',
#  'Sector(s) affected',
#  'Objective(s)',
#  'Total GHG emissions reductions in 2020 (kt CO2eq/y)',
#  'Total GHG emissions reductions in 2030 (kt CO2eq/y)',
#  'Entities responsible for implementing the policy (type)',
#  'Entities responsible for implementing the policy',
#  'Implementation period start',
#  'Is the policy or measure related to a Union policy?',
#  'Related Union Policy',
#  'GHG(s) affected',
#  'Projection scenario in which the policy or measure is included',
#  'Link to national report',
#  'Description',
#  'Quantified objective',
#  'Implementation period finish',
#  'Indicator used to monitor and evaluate progress over time',
#  'General comment',
#  'Main reference',
#  'URL to main reference',
#  'GHG emissions reductions EU ETS in 2020 (kt CO2eq/y)',
#  'GHG emissions reductions ESD in 2020 (kt CO2eq/y)',
#  'GHG emissions reductions EU ETS in 2025 (kt CO2eq/y)',
#  'GHG emissions reductions ESD in 2025 (kt CO2eq/y)',
#  'Total GHG emissions reductions in 2025 (kt CO2eq/y)',
#  'GHG emissions reductions EU ETS in 2030 (kt CO2eq/y)',
#  'GHG emissions reductions ESD in 2030 (kt CO2eq/y)',
#  'GHG emissions reductions EU ETS in 2035 (kt CO2eq/y)',
#  'GHG emissions reductions ESD in 2035 (kt CO2eq/y)',
#  'Total GHG emissions reductions in 2035 (kt CO2eq/y)',
#  'Reference for ex-ante assessment',
#  'Web link for ex-ante assessment',
#  'Year for which reduction applies (ex post)',
#  'Average ex post emission reduction (kt CO2eq/y)',
#  'Explanation of the basis for the mitigation estimates',
#  'Factors affected by the policy or measure',
#  'Reference for ex-post assessment',
#  'Web link for ex-post assessment',
#  'Projected costs (EUR per tonne CO2eq reduced/ sequestered)',
#  'Projected absolute costs per year (EUR)',
#  'Year projected cost has been calculated for',
#  'Price reference year (projected costs)',
#  'Projected benefits (EUR per tonne CO2eq reduced/ sequestered)',
#  'Projected absolute benefit per year (EUR)',
#  'Projected net costs (EUR per tonne CO2eq reduced/ sequestered)',
#  'Projected net cost per year (EUR)',
#  'Description of projected cost estimates',
#  'Reference for projected costs and benefits',
#  'Web link for projected costs and benefits',
#  'Realised costs  (EUR per tonne CO2eq reduced/ sequestered)',
#  'Realised absolute costs per year (EUR)',
#  'Year realised cost has been calculated for',
#  'Price reference year (realised costs)',
#  'Realised benefits (EUR per tonne CO2eq reduced/ sequestered)',
#  'Realised absolute benefit per year (EUR)',
#  'Realised net costs (EUR per tonne CO2eq reduced/ sequestered)',
#  'Realised net cost per year (EUR)',
#  'Description of realised cost estimates',
#  'Reference for realised costs and benefits',
#  'Web link for realised costs and benefits',
#  'Projected net cost per year (EUR).1',
#  'Realised net cost per year (EUR).1']

# %%
#drop columns
eea_db = eea_db.drop(['ID of policy or measure', 
             'Report ID ES', 
             'Single policy or measure, or group of measures', 
             'Report_ID', 
             'Projection scenario in which the policy or measure is included', 
             'Quantified objective', 
             'Indicator used to monitor and evaluate progress over time', 
             'Link to national report', 
             'General comment',
             'Main reference',
             'GHG emissions reductions EU ETS in 2020 (kt CO2eq/y)',
             'GHG emissions reductions ESD in 2020 (kt CO2eq/y)',
             'GHG emissions reductions EU ETS in 2025 (kt CO2eq/y)',
             'GHG emissions reductions ESD in 2025 (kt CO2eq/y)',
             'GHG emissions reductions EU ETS in 2030 (kt CO2eq/y)',
             'GHG emissions reductions ESD in 2030 (kt CO2eq/y)',
             'GHG emissions reductions EU ETS in 2035 (kt CO2eq/y)',
             'GHG emissions reductions ESD in 2035 (kt CO2eq/y)',
             'Reference for ex-ante assessment',
             'Web link for ex-ante assessment',
             'Year for which reduction applies (ex post)',
             'Average ex post emission reduction (kt CO2eq/y)',
             'Explanation of the basis for the mitigation estimates',
             'Factors affected by the policy or measure',
             'Reference for ex-post assessment',
             'Web link for ex-post assessment',
             'Projected costs (EUR per tonne CO2eq reduced/ sequestered)',
             'Projected absolute costs per year (EUR)',
             'Year projected cost has been calculated for',
             'Price reference year (projected costs)',
             'Projected benefits (EUR per tonne CO2eq reduced/ sequestered)',
             'Projected absolute benefit per year (EUR)',
             'Projected net costs (EUR per tonne CO2eq reduced/ sequestered)',
             'Projected net cost per year (EUR)',
             'Description of projected cost estimates',
             'Reference for projected costs and benefits',
             'Web link for projected costs and benefits',
             'Realised costs  (EUR per tonne CO2eq reduced/ sequestered)',
             'Realised absolute costs per year (EUR)',
             'Year realised cost has been calculated for',
             'Price reference year (realised costs)',
             'Realised benefits (EUR per tonne CO2eq reduced/ sequestered)',
             'Realised absolute benefit per year (EUR)',
             'Realised net costs (EUR per tonne CO2eq reduced/ sequestered)',
             'Realised net cost per year (EUR)',
             'Description of realised cost estimates',
             'Reference for realised costs and benefits',
             'Web link for realised costs and benefits',
             'Projected net cost per year (EUR).1',
             'Realised net cost per year (EUR).1',
             'Total GHG emissions reductions in 2025 (kt CO2eq/y)',
             'Total GHG emissions reductions in 2035 (kt CO2eq/y)',        
             'Objective(s)'], axis = 1)

list(eea_db.columns)
# Out:
# ['Country',
#  'Name of policy or measure',
#  'Policies or measures included in the group',
#  'Type of policy instrument',
#  'Status of implementation',
#  'Policy impacting EU ETS, ESD or LULUCF emissions',
#  'Sector(s) affected',
#  'Total GHG emissions reductions in 2020 (kt CO2eq/y)',
#  'Total GHG emissions reductions in 2030 (kt CO2eq/y)',
#  'Entities responsible for implementing the policy (type)',
#  'Entities responsible for implementing the policy',
#  'Implementation period start',
#  'Is the policy or measure related to a Union policy?',
#  'Related Union Policy',
#  'GHG(s) affected',
#  'Description',
#  'Implementation period finish',
#  'URL to main reference']

# %%
#rename columns for our db schema
eea_db.rename(columns={'Country': 'country',
                 'Name of policy or measure': 'name',
                 'Policies or measures included in the group': 'related_documents',
                 'Type of policy instrument': 'policy_type',
                 'Status of implementation': 'policy_status',
                 'Policy impacting EU ETS, ESD or LULUCF emissions': 'impact_on_eu_ets_esd_or_lulucf_emissions',
                 'Sector(s) affected': 'policy_target',
                 'Total GHG emissions reductions in 2020 (kt CO2eq/y)': 'total_ghg_emissions_reductions_in_2020',
                 'Total GHG emissions reductions in 2030 (kt CO2eq/y)': 'total_ghg_emissions_reductions_in_2030',
                 'Entities responsible for implementing the policy (type)': 'jurisdiction',
                 'Entities responsible for implementing the policy': 'agency',
                 'Implementation period start': 'policy_implementation_period_start_year',
                 'Is the policy or measure related to a Union policy?': 'related_to_eu_policy_boolean',
                 'Related Union Policy': 'related_to_eu_policy',
                 'GHG(s) affected': 'ghgs_affected',
                 'Description': 'description',
                 'Implementation period finish': 'policy_implementation_period_end_year',
                 'URL to main reference': 'link'}, inplace=True)

list(eea_db.columns)
# Out:
# ['country',
#  'name',
#  'related_documents',
#  'policy_type',
#  'policy_status',
#  'impact_on_eu_ets_esd_or_lulucf_emissions',
#  'policy_target',
#  'total_ghg_emissions_reductions_in_2020',
#  'total_ghg_emissions_reductions_in_2030',
#  'jurisdiction',
#  'agency',
#  'policy_implementation_period_start_year',
#  'related_to_eu_policy_boolean',
#  'related_to_eu_policy',
#  'ghgs_affected',
#  'description',
#  'policy_implementation_period_end_year',
#  'link']

# %%
#add in missing features
eea_db['data_source'] = 'eea'
eea_db['world_region'] = np.nan
eea_db['country_region'] = np.nan
eea_db['city'] = np.nan
eea_db['policy_written_year'] = np.nan
eea_db['impact_evaluation'] = np.nan
eea_db['policy_financing_quantity'] = np.nan
eea_db['policy_financing_period_start'] = np.nan
eea_db['policy_financing_period_end'] = np.nan
eea_db['percent_private_funded'] = np.nan
eea_db['related_to_neeap_policy'] = np.nan
eea_db['related_to_neeap_policy_boolean'] = np.nan

list(eea_db.columns)
# Out:
# ['country',
#  'name',
#  'related_documents',
#  'policy_type',
#  'policy_status',
#  'impact_on_eu_ets_esd_or_lulucf_emissions',
#  'policy_target',
#  'total_ghg_emissions_reductions_in_2020',
#  'total_ghg_emissions_reductions_in_2030',
#  'jurisdiction',
#  'agency',
#  'policy_implementation_period_start_year',
#  'related_to_eu_policy_boolean',
#  'related_to_eu_policy',
#  'ghgs_affected',
#  'description',
#  'policy_implementation_period_end_year',
#  'link',
#  'data_source',
#  'world_region',
#  'country_region',
#  'city',
#  'policy_written_year',
#  'impact_evaluation',
#  'policy_financing_quantity',
#  'policy_financing_period_start',
#  'policy_financing_period_end',
#  'percent_private_funded',
#  'related_to_neeap_policy',
#  'related_to_neeap_policy_boolean']

# %%
#drop columns not in schema
eea_dropped = ['ID of policy or measure', 
             'Report ID ES', 
             'Single policy or measure, or group of measures', 
             'Report_ID', 
             'Projection scenario in which the policy or measure is included', 
             'Quantified objective', 
             'Indicator used to monitor and evaluate progress over time', 
             'Link to national report', 
             'General comment',
             'Main reference',
             'GHG emissions reductions EU ETS in 2020 (kt CO2eq/y)',
             'GHG emissions reductions ESD in 2020 (kt CO2eq/y)',
             'GHG emissions reductions EU ETS in 2025 (kt CO2eq/y)',
             'GHG emissions reductions ESD in 2025 (kt CO2eq/y)',
             'GHG emissions reductions EU ETS in 2030 (kt CO2eq/y)',
             'GHG emissions reductions ESD in 2030 (kt CO2eq/y)',
             'GHG emissions reductions EU ETS in 2035 (kt CO2eq/y)',
             'GHG emissions reductions ESD in 2035 (kt CO2eq/y)',
             'Reference for ex-ante assessment',
             'Web link for ex-ante assessment',
             'Year for which reduction applies (ex post)',
             'Average ex post emission reduction (kt CO2eq/y)',
             'Explanation of the basis for the mitigation estimates',
             'Factors affected by the policy or measure',
             'Reference for ex-post assessment',
             'Web link for ex-post assessment',
             'Projected costs (EUR per tonne CO2eq reduced/ sequestered)',
             'Projected absolute costs per year (EUR)',
             'Year projected cost has been calculated for',
             'Price reference year (projected costs)',
             'Projected benefits (EUR per tonne CO2eq reduced/ sequestered)',
             'Projected absolute benefit per year (EUR)',
             'Projected net costs (EUR per tonne CO2eq reduced/ sequestered)',
             'Projected net cost per year (EUR)',
             'Description of projected cost estimates',
             'Reference for projected costs and benefits',
             'Web link for projected costs and benefits',
             'Realised costs  (EUR per tonne CO2eq reduced/ sequestered)',
             'Realised absolute costs per year (EUR)',
             'Year realised cost has been calculated for',
             'Price reference year (realised costs)',
             'Realised benefits (EUR per tonne CO2eq reduced/ sequestered)',
             'Realised absolute benefit per year (EUR)',
             'Realised net costs (EUR per tonne CO2eq reduced/ sequestered)',
             'Realised net cost per year (EUR)',
             'Description of realised cost estimates',
             'Reference for realised costs and benefits',
             'Web link for realised costs and benefits',
             'Projected net cost per year (EUR).1',
             'Realised net cost per year (EUR).1',
             'Total GHG emissions reductions in 2025 (kt CO2eq/y)',
             'Total GHG emissions reductions in 2035 (kt CO2eq/y)',        
             'Objective(s)']

print("Dropped:", ", ".join(eea_dropped))
# Out:
# Dropped: ID of policy or measure, Report ID ES, Single policy or measure, or group of measures, Report_ID, Projection scenario in which the policy or measure is included, Quantified objective, Indicator used to monitor and evaluate progress over time, Link to national report, General comment, Main reference, GHG emissions reductions EU ETS in 2020 (kt CO2eq/y), GHG emissions reductions ESD in 2020 (kt CO2eq/y), GHG emissions reductions EU ETS in 2025 (kt CO2eq/y), GHG emissions reductions ESD in 2025 (kt CO2eq/y), GHG emissions reductions EU ETS in 2030 (kt CO2eq/y), GHG emissions reductions ESD in 2030 (kt CO2eq/y), GHG emissions reductions EU ETS in 2035 (kt CO2eq/y), GHG emissions reductions ESD in 2035 (kt CO2eq/y), Reference for ex-ante assessment, Web link for ex-ante assessment, Year for which reduction applies (ex post), Average ex post emission reduction (kt CO2eq/y), Explanation of the basis for the mitigation estimates, Factors affected by the policy or measure, Reference for ex-post assessment, Web link for ex-post assessment, Projected costs (EUR per tonne CO2eq reduced/ sequestered), Projected absolute costs per year (EUR), Year projected cost has been calculated for, Price reference year (projected costs), Projected benefits (EUR per tonne CO2eq reduced/ sequestered), Projected absolute benefit per year (EUR), Projected net costs (EUR per tonne CO2eq reduced/ sequestered), Projected net cost per year (EUR), Description of projected cost estimates, Reference for projected costs and benefits, Web link for projected costs and benefits, Realised costs  (EUR per tonne CO2eq reduced/ sequestered), Realised absolute costs per year (EUR), Year realised cost has been calculated for, Price reference year (realised costs), Realised benefits (EUR per tonne CO2eq reduced/ sequestered), Realised absolute benefit per year (EUR), Realised net costs (EUR per tonne CO2eq reduced/ sequestered), Realised net cost per year (EUR), Description of realised cost estimates, Reference for realised costs and benefits, Web link for realised costs and benefits, Projected net cost per year (EUR).1, Realised net cost per year (EUR).1, Total GHG emissions reductions in 2025 (kt CO2eq/y), Total GHG emissions reductions in 2035 (kt CO2eq/y), Objective(s)

# %%
#export
eea_db.to_csv(path_or_buf='/data/eea_db.csv', index=False)

# %%
#test exported csv
eea = pd.read_csv('data/eea_db.csv')
eea.columns
# Out:
# Index(['country', 'name', 'related_documents', 'policy_type', 'policy_status',
#        'impact_on_eu_ets_esd_or_lulucf_emissions', 'policy_target',
#        'total_ghg_emissions_reductions_in_2020',
#        'total_ghg_emissions_reductions_in_2030', 'jurisdiction', 'agency',
#        'policy_implementation_period_start_year',
#        'related_to_eu_policy_boolean', 'related_to_eu_policy', 'ghgs_affected',
#        'description', 'policy_implementation_period_end_year', 'link',
#        'data_source', 'world_region', 'country_region', 'city',
#        'policy_written_year', 'impact_evaluation', 'policy_financing_quantity',
#        'policy_financing_period_start', 'policy_financing_period_end',
#        'percent_private_funded', 'related_to_neeap_policy',
#        'related_to_neeap_policy_boolean'],
#       dtype='object')

# %%
eea_countries = eea['country'].tolist()
set(eea_countries)
# Out:
# {'Austria',
#  'Belgium',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Ireland',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Netherlands',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'United Kingdom'}

# %% [markdown]
# ## MURE

# %% [markdown]
# ### How this dataset was originated:
#
# MURE (Mesures d'Utilisation Rationnelle de l'Energie) provides information on energy efficiency policies and measures that have been carried out in the Member States of the European Union. MURE is regularly updated by the network of national teams (once to twice a year). A network of 36 partners from 31 countries participate to the Odyssee-Mure project, usually national Efficiency Agencies or their representatives within the European network of energy efficiency agencies.
# <sup>1</sup>
#
# ___
# <sup>1</sup>"Project Overview", Odyssee-MURE. Retrieved September 15, 2019 (https://www.odyssee-mure.eu/project.html)

# %% [markdown]
# ### How we got this data:
#
# To retrieve this data we created a csv file of the entire database using google sheets and copy and paste and then used pandas to convert it to a pandas dataframe, selected relevant features for our dataset and exported them to a new csv for seeding our database.

# %%
#load in data export
mure_data = pd.read_excel('data/source/muredata.xlsx')
mure_data.head()
# Out:
#        Code                                               Link     Sector  \
# 0  HOU-AU13  http://www.measures-odyssee-mure.eu/output2_mr...  Household
# 1  HOU-AU27  http://www.measures-odyssee-mure.eu/output2_mr...  Household
# 2   HOU-AU5  http://www.measures-odyssee-mure.eu/output2_mr...  Household
# 3  HOU-AU18  http://www.measures-odyssee-mure.eu/output2_mr...  Household
# 4  HOU-AU28  http://www.measures-odyssee-mure.eu/output2_mr...  Household
#
#                                      Title   Status  \
# 0             Residential building subsidy  Ongoing
# 1    Energy audits (advice) for households  Ongoing
# 2  Minimum thermal standards for buildings  Ongoing
# 3  klimaaktiv building - building standard  Ongoing
# 4   Smart Metering and Informative Billing  Ongoing
#
#                                Type  Starting Year Description (Open PDF)
# 0                         Financial         1982.0                    YES
# 1  Financial, Information/Education         1990.0                    YES
# 2             Legislative/Normative         1991.0                    YES
# 3             Information/Education         2005.0                    YES
# 4  Financial, Information/Education         2008.0                    YES

# %%
#get links for each entry detail
mure_links = mure_data['Link'].tolist()
len(mure_links)
# Out:
# 2494

# %%
mure_links[4]
# Out:
# 'http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=AU28'

# %%
#test entry detail methodology
sample = mure_links[0]

entry = {}

get_sample = session.get(sample)

soup_s = BeautifulSoup(get_sample.text, 'html.parser')
trows = soup_s.find_all("tr",)
#trows = tables.find_all('tr')

column = [t.find_all("td") for t in trows]
for t in column:
                if len(t) == 2:
                    header = t[0].get_text()    
                    
                    for e in t[1]: 
                        text = e.get_text()
                        entry[header] = text
                        #print(header, text)

#evals = trows[:-2]
#print(evals)
#get index and merge
entry
# Out:
# {'Actors': 'central government, energy agencies, local government',
#  'Country': 'Austria',
#  'Financing': '\x80 590.000.000 from 2009 to 2015',
#  'Measure Code': 'HOU-AU13',
#  'Reference': 'https://www.bmlfuw.gv.at/\r\nhttp://www.bmwfw.gv.at/Seiten/default.aspx',
#  'Target Audience': 'housing associations, landlords, owner-occupiers',
#  'Targeted End Use': 'Total final consumption , Space heating (+elec.), Hot water (+elec.)',
#  'Title': 'Residential building subsidy ',
#  'Types': '21) Financial - Grants / Subsidies - For investments in new buildings exceeding building regulation; 23) Financial - Grants / Subsidies - For the purchase of more efficient boilers; 25) Financial - Grants / Subsidies - For other energy efficiency investments\xa0; 26) Financial - Grants / Subsidies - For investment in renewables'}

# %%
mure_paired = mure_links[0:10]
mure_paired
# Out:
# ['http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=AU13',
#  'http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=AU27',
#  'http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=AU5',
#  'http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=AU18',
#  'http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=AU28',
#  'http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=AU26',
#  'http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=AU21',
#  'http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=BEL19',
#  'http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=BEL23',
#  'http://www.measures-odyssee-mure.eu/output2_mr.asp?Cod=BEL15']

# %%
#use threaded approach from above to scrape each entry detail

mure_set = []

async def main():
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:

        loop = asyncio.get_event_loop()
        futures = [
            loop.run_in_executor(
                executor, 
                session.get, 
                link
            )
            for link in mure_links
            
        ]
        
        for response in await asyncio.gather(*futures):
            
            entries = dict()    
            soup_s = BeautifulSoup(response.text, 'html.parser')
            trows = soup_s.find_all("tr",)
            #trows = tables.find_all('tr')

            column = [t.find_all("td") for t in trows]
            for t in column:
                if len(t) == 2:
                    header = t[0].get_text()
                    text = t[1].get_text()

                    entries[header] = text

            entries["data_source"] = "MURE"
            
            mure_set.append(entries)
            
loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
mure_set[7]
# Out:
# {'Actors': 'central government, local government',
#  'Country': 'Belgium',
#  'Financing': '\x80 0 from  to ',
#  'Measure Code': 'HOU-BEL19',
#  'Reference': 'Wallonia: decree 1/05/85; Flanders: decree 1/09/92; Bruxelles : decree 1/1/2000',
#  'Target Audience': 'building professions',
#  'Targeted End Use': 'Space heating (+elec.)',
#  'Title': 'K-level thermal regulations of residential buildings (in use prior to the EPB directive)',
#  'Types': '2) Legislative/Normative - Mandatory Standards for Buildings - Minimum thermal insulation standards\xa0',
#  'data_source': 'MURE'}

# %%
#pt in dataframe
mure_db = pd.DataFrame(mure_set)

mure_db = mure_db.rename(columns = {'Measure Code': 'Code'})
mure_db = mure_db.drop(['Title'], axis=1)

mure_db.head()
# Out:
#                                               Actors Area  Country  \
# 0  central government, energy agencies, local gov...  NaN  Austria
# 1                                   local government  NaN  Austria
# 2                                   local government  NaN  Austria
# 3  associations, central government, energy agencies  NaN  Austria
# 4                                          utilities  NaN  Austria
#
#                          Financing Industry sector      Code  \
# 0   590.000.000 from 2009 to 2015             NaN  HOU-AU13
# 1                     0 from  to              NaN  HOU-AU27
# 2                     0 from  to              NaN   HOU-AU5
# 3                     0 from  to              NaN  HOU-AU18
# 4                     0 from  to              NaN  HOU-AU28
#
#                                            Reference Stages  \
# 0  https://www.bmlfuw.gv.at/\r\nhttp://www.bmwfw....    NaN
# 1                             NEEAP 2014, NEEAP 2017    NaN
# 2  Vereinbarung gem. Art. 15a B-VG, BGBl.Nr. 388/...    NaN
# 3            http://www.klimaaktiv.at/bauen-sanieren    NaN
# 4                  2nd NEEAP, NEEAP 2014, NEEAP 2017    NaN
#
#                                      Target Audience  \
# 0   housing associations, landlords, owner-occupiers
# 1  building professions, housing associations, la...
# 2  building professions, housing associations, la...
# 3  building professions, general public, housing ...
# 4  housing associations, landlords, owner-occupie...
#
#                                     Targeted End Use Tertiary sector  \
# 0  Total final consumption , Space heating (+elec...             NaN
# 1  Space heating (+elec.), Space cooling, Hot wat...             NaN
# 2  Space cooling, Total final consumption , Space...             NaN
# 3  Space heating (+elec.), Hot water (+elec.), Sp...             NaN
# 4                        Total electric consumption              NaN
#
#                                                Types data_source
# 0  21) Financial - Grants / Subsidies - For inves...        MURE
# 1  28) Financial - Grants / Subsidies - For energ...        MURE
# 2  2) Legislative/Normative - Mandatory Standards...        MURE
# 3  36) Information/Education - Voluntary labellin...        MURE
# 4  30) Financial - Loans/Others - Leasing of ener...        MURE

# %%
mure_columns = mure_db.columns.tolist()

mure_columns
# Out:
# ['Actors',
#  'Area',
#  'Country',
#  'Financing',
#  'Industry sector',
#  'Code',
#  'Reference',
#  'Stages',
#  'Target Audience',
#  'Targeted End Use',
#  'Tertiary sector',
#  'Types',
#  'data_source']

# %%
#add in detail data
mure_full = pd.merge(mure_data, mure_db[mure_columns], on='Code')

mure_full.head()
# Out:
#        Code                                               Link     Sector  \
# 0  HOU-AU13  http://www.measures-odyssee-mure.eu/output2_mr...  Household
# 1  HOU-AU27  http://www.measures-odyssee-mure.eu/output2_mr...  Household
# 2   HOU-AU5  http://www.measures-odyssee-mure.eu/output2_mr...  Household
# 3  HOU-AU18  http://www.measures-odyssee-mure.eu/output2_mr...  Household
# 4  HOU-AU28  http://www.measures-odyssee-mure.eu/output2_mr...  Household
#
#                                      Title   Status  \
# 0             Residential building subsidy  Ongoing
# 1    Energy audits (advice) for households  Ongoing
# 2  Minimum thermal standards for buildings  Ongoing
# 3  klimaaktiv building - building standard  Ongoing
# 4   Smart Metering and Informative Billing  Ongoing
#
#                                Type  Starting Year Description (Open PDF)  \
# 0                         Financial         1982.0                    YES
# 1  Financial, Information/Education         1990.0                    YES
# 2             Legislative/Normative         1991.0                    YES
# 3             Information/Education         2005.0                    YES
# 4  Financial, Information/Education         2008.0                    YES
#
#                                               Actors Area  Country  \
# 0  central government, energy agencies, local gov...  NaN  Austria
# 1                                   local government  NaN  Austria
# 2                                   local government  NaN  Austria
# 3  associations, central government, energy agencies  NaN  Austria
# 4                                          utilities  NaN  Austria
#
#                          Financing Industry sector  \
# 0   590.000.000 from 2009 to 2015             NaN
# 1                     0 from  to              NaN
# 2                     0 from  to              NaN
# 3                     0 from  to              NaN
# 4                     0 from  to              NaN
#
#                                            Reference Stages  \
# 0  https://www.bmlfuw.gv.at/\r\nhttp://www.bmwfw....    NaN
# 1                             NEEAP 2014, NEEAP 2017    NaN
# 2  Vereinbarung gem. Art. 15a B-VG, BGBl.Nr. 388/...    NaN
# 3            http://www.klimaaktiv.at/bauen-sanieren    NaN
# 4                  2nd NEEAP, NEEAP 2014, NEEAP 2017    NaN
#
#                                      Target Audience  \
# 0   housing associations, landlords, owner-occupiers
# 1  building professions, housing associations, la...
# 2  building professions, housing associations, la...
# 3  building professions, general public, housing ...
# 4  housing associations, landlords, owner-occupie...
#
#                                     Targeted End Use Tertiary sector  \
# 0  Total final consumption , Space heating (+elec...             NaN
# 1  Space heating (+elec.), Space cooling, Hot wat...             NaN
# 2  Space cooling, Total final consumption , Space...             NaN
# 3  Space heating (+elec.), Hot water (+elec.), Sp...             NaN
# 4                        Total electric consumption              NaN
#
#                                                Types data_source
# 0  21) Financial - Grants / Subsidies - For inves...        MURE
# 1  28) Financial - Grants / Subsidies - For energ...        MURE
# 2  2) Legislative/Normative - Mandatory Standards...        MURE
# 3  36) Information/Education - Voluntary labellin...        MURE
# 4  30) Financial - Loans/Others - Leasing of ener...        MURE

# %%
mure_final = mure_full.drop_duplicates(subset=None, keep='first', inplace=False)
mure_final.columns.tolist()
# Out:
# ['Code',
#  'Link',
#  'Sector',
#  'Title',
#  'Status',
#  'Type',
#  'Starting Year',
#  'Description (Open PDF)',
#  'Actors',
#  'Area',
#  'Country',
#  'Financing',
#  'Industry sector',
#  'Reference',
#  'Stages',
#  'Target Audience',
#  'Targeted End Use',
#  'Tertiary sector',
#  'Types',
#  'data_source']

# %%
##our schema columns

['country',
 'name',
 'related_documents',
 'policy_type',
 'policy_status',
 'impact_on_eu_ets_esd_or_lulucf_emissions',
 'policy_target',
 'total_ghg_emissions_reductions_in_2020',
 'total_ghg_emissions_reductions_in_2030',
 'jurisdiction',
 'agency',
 'policy_implementation_period_start_year',
 'related_to_eu_policy_boolean',
 'related_to_eu_policy',
 'ghgs_affected',
 'description',
 'policy_implementation_period_end_year',
 'link',
 'data_source',
 'world_region',
 'country_region',
 'city',
 'policy_written_year',
 'impact_evaluation',
 'policy_financing_quantity',
 'policy_financing_period_start',
 'policy_financing_period_end',
 'percent_private_funded',
 'related_to_neeap_policy',
 'related_to_neeap_policy_boolean']

## need to split finaincing into the three columns, need to do NEEAP boolean based off text search or EU boolean


mure_dat = mure_final.copy(deep=True)

mure_dat.rename(columns={'Link':'link',
                         'Industry sector':'policy_target',
                         'Title':'name',
                         'Status':'policy_status',
                         'Type':'policy_type',
                         'Starting Year':'policy_implementation_period_start_year',
                         'Actors':'jurisdiction',
                         'Country':'country',
                         'Financing':'policy_financing_quantity',
                         'Reference':'related_documents'}, inplace=True)

mure_dat.columns.tolist()
# Out:
# ['Code',
#  'link',
#  'Sector',
#  'name',
#  'policy_status',
#  'policy_type',
#  'policy_implementation_period_start_year',
#  'Description (Open PDF)',
#  'jurisdiction',
#  'Area',
#  'country',
#  'policy_financing_quantity',
#  'policy_target',
#  'related_documents',
#  'Stages',
#  'Target Audience',
#  'Targeted End Use',
#  'Tertiary sector',
#  'Types',
#  'data_source']

# %%
## drop features not in schema for now
mure_dat.drop(['Code',
                 'Sector',
                 'Description (Open PDF)',
                 'Tertiary sector',
                 'Area',
                 'Stages',
                 'Types',
                 'Targeted End Use',
                 'Target Audience'], axis=1, inplace=True)

m_drop = ['Code', 'Sector','Description (Open PDF)', 'Tertiary sector','Area','Stages','Types','Targeted End Use','Target Audience']

print("Dropped columns:\n", m_drop)
# Out:
# Dropped columns:
#  ['Code', 'Sector', 'Description (Open PDF)', 'Tertiary sector', 'Area', 'Stages', 'Types', 'Targeted End Use', 'Target Audience']

# %%
#input missing features

mure_dat['agency']= np.nan
mure_dat['related_to_eu_policy_boolean'] = np.nan
mure_dat['related_to_eu_policy'] = np.nan
mure_dat['ghgs_affected'] = np.nan
mure_dat['description'] = np.nan
mure_dat['policy_implementation_period_end_year'] = np.nan
mure_dat['impact_on_eu_ets_esd_or_lulucf_emissions'] = np.nan
mure_dat['total_ghg_emissions_reductions_in_2020'] = np.nan
mure_dat['total_ghg_emissions_reductions_in_2030'] = np.nan
mure_dat['world_region'] = np.nan
mure_dat['country_region'] = np.nan
mure_dat['city'] = np.nan
mure_dat['policy_written_year'] = np.nan
mure_dat['impact_evaluation'] = np.nan
mure_dat['policy_financing_period_start'] = np.nan
mure_dat['policy_financing_period_end'] = np.nan
mure_dat['percent_private_funded'] = np.nan
mure_dat['related_to_neeap_policy'] = np.nan
mure_dat['related_to_neeap_policy_boolean'] = np.nan

mure_dat.head()
# Out:
#                                                 link  \
# 0  http://www.measures-odyssee-mure.eu/output2_mr...
# 1  http://www.measures-odyssee-mure.eu/output2_mr...
# 2  http://www.measures-odyssee-mure.eu/output2_mr...
# 3  http://www.measures-odyssee-mure.eu/output2_mr...
# 4  http://www.measures-odyssee-mure.eu/output2_mr...
#
#                                       name policy_status  \
# 0             Residential building subsidy       Ongoing
# 1    Energy audits (advice) for households       Ongoing
# 2  Minimum thermal standards for buildings       Ongoing
# 3  klimaaktiv building - building standard       Ongoing
# 4   Smart Metering and Informative Billing       Ongoing
#
#                         policy_type  policy_implementation_period_start_year  \
# 0                         Financial                                   1982.0
# 1  Financial, Information/Education                                   1990.0
# 2             Legislative/Normative                                   1991.0
# 3             Information/Education                                   2005.0
# 4  Financial, Information/Education                                   2008.0
#
#                                         jurisdiction  country  \
# 0  central government, energy agencies, local gov...  Austria
# 1                                   local government  Austria
# 2                                   local government  Austria
# 3  associations, central government, energy agencies  Austria
# 4                                          utilities  Austria
#
#          policy_financing_quantity policy_target  \
# 0   590.000.000 from 2009 to 2015           NaN
# 1                     0 from  to            NaN
# 2                     0 from  to            NaN
# 3                     0 from  to            NaN
# 4                     0 from  to            NaN
#
#                                    related_documents  \
# 0  https://www.bmlfuw.gv.at/\r\nhttp://www.bmwfw....
# 1                             NEEAP 2014, NEEAP 2017
# 2  Vereinbarung gem. Art. 15a B-VG, BGBl.Nr. 388/...
# 3            http://www.klimaaktiv.at/bauen-sanieren
# 4                  2nd NEEAP, NEEAP 2014, NEEAP 2017
#
#                 ...                world_region  country_region  city  \
# 0               ...                         NaN             NaN   NaN
# 1               ...                         NaN             NaN   NaN
# 2               ...                         NaN             NaN   NaN
# 3               ...                         NaN             NaN   NaN
# 4               ...                         NaN             NaN   NaN
#
#    policy_written_year  impact_evaluation  policy_financing_period_start  \
# 0                  NaN                NaN                            NaN
# 1                  NaN                NaN                            NaN
# 2                  NaN                NaN                            NaN
# 3                  NaN                NaN                            NaN
# 4                  NaN                NaN                            NaN
#
#    policy_financing_period_end  percent_private_funded  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
#    related_to_neeap_policy  related_to_neeap_policy_boolean
# 0                      NaN                              NaN
# 1                      NaN                              NaN
# 2                      NaN                              NaN
# 3                      NaN                              NaN
# 4                      NaN                              NaN
#
# [5 rows x 30 columns]

# %%
mure_dat.to_csv(path_or_buf='data/mure_db.csv', index=False)

# %%
mure_countries = mure_final['Country'].tolist()
set(mure_countries)
# Out:
# {'Austria',
#  'Belgium',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'European Union',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Ireland',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'United Kingdom'}

# %%
mure_slice = mure_final.rename

# %% [markdown]
# ## Private Participation Renewable Energy

# %% [markdown]
# ### How this dataset was originated:
#
# Private Participation Renewable Energy collects data on private participation in renewable energy in developing countries. It is part of the PPI Database and applies the same research methdology. It database relies on public sources which in most cases provide a good picture of contracts. However, in some cases they may not be accurate or contain all the required information. In such cases, the database reports the project data which seems to be the most accurate. When unable to obtain more information, projects are included with the limited information available.<sup>1</sup>
#
# ___
# <sup>1</sup>"Private Participation In Renewable Energy", The World Bank. Retrieved September 27, 2019 (https://www.odyssee-mure.eu/project.html)

# %% [markdown]
# ### How we got this data:
#
# To retrieve this data we downloaded a csv file of the entire database and used pandas to convert it to a pandas dataframe, selected relevant features for our dataset and exported them to a new csv for seeding our database.

# %%
#read in data
private = pd.read_csv('data/source/privateprojects.csv', encoding = "utf-8")
print(private.shape)
private.head()
# Out:
# (1221, 60)
#    projectID                 Region   Country IncomeGroup IDA Status  \
# 0       4571  East Asia and Pacific  Cambodia  Low income        IDA
# 1       4571  East Asia and Pacific  Cambodia  Low income        IDA
# 2       7189  East Asia and Pacific  Cambodia  Low income        IDA
# 3       4569  East Asia and Pacific  Cambodia  Low income        IDA
# 4       4573  East Asia and Pacific  Cambodia  Low income        IDA
#
#    Financial closure year Financial closure Month  \
# 0                    2001                   April
# 1                    2001                   April
# 2                    2007                   April
# 3                    2007               September
# 4                    2007                   April
#
#                           Project name                  RelatedNames  \
# 0  Kirirom 1 and 3 Hydropower Stations  Kirium Hydro Station Project
# 1  Kirirom 1 and 3 Hydropower Stations  Kirium Hydro Station Project
# 2         ABC Phnom Penh Biomass Plant                           NaN
# 3           Kamchay Hydropower Station                           NaN
# 4  Stung Atay River Hydropower Station                           NaN
#
#           Type of PPI         ...          CommissioningDate ProjectGrid  \
# 0          Concession         ...                        NaN         NaN
# 1          Concession         ...                        NaN         NaN
# 2  Greenfield project         ...                     2007.0    Cambodia
# 3  Greenfield project         ...                     2009.0    Cambodia
# 4  Greenfield project         ...                        NaN         NaN
#
#   CarbonCredits  FundingYear PrivateFunding PublicFunding GovtFunding  \
# 0           NaN          NaN            NaN           NaN         NaN
# 1           NaN          NaN            NaN           NaN         NaN
# 2           Yes          NaN            NaN           NaN         NaN
# 3            No          NaN            NaN           NaN         NaN
# 4            No          NaN            NaN           NaN         NaN
#
#   BankLocalFunding DonorFunding DebtEquityGrantRatio
# 0              NaN          NaN                  NaN
# 1              NaN          NaN                  NaN
# 2              NaN          NaN                  NaN
# 3              NaN          NaN                  NaN
# 4              NaN          NaN                  NaN
#
# [5 rows x 60 columns]

# %%
#test pulling random row
private.iloc[200]
# Out:
# projectID                                              3399
# Region                                East Asia and Pacific
# Country                                         Philippines
# IncomeGroup                             Lower middle income
# IDA Status                                          Non-IDA
# Financial closure year                                 2004
# Financial closure Month                                July
# Project name                      Barit Hydroelectric Plant
# RelatedNames                                            NaN
# Type of PPI                                     Divestiture
# Subtype of PPI                                         Full
# Project status                                  Operational
# Primary sector                                       Energy
# Secondary sector                                        NaN
# Subsector                                       Electricity
# Segment                              Electricity generation
# Location                             Camarines Sur province
# ContractPeriod                                          NaN
# TerminationYear                                         NaN
# PubliclyTraded                                           No
# StockExchange                                           NaN
# MultipleSystems                                          No
# NumberOfSystems                                           1
# CaptiveFacility                                          No
# SharePercent                                            NaN
# GovtGrantingContract                                Federal
# TypeOfGovtSupport                                       NaN
# InvestmentYear                                         2004
# PercentPrivate                                          100
# GovtPaymentCommitments                                 0.48
# PhysicalAssets                                            0
# TotalInvestment                                        0.48
# GovCashAssist                                           NaN
# dateStatusUpdated                                       NaN
# CapacityType                                             MW
# Capacity                                                1.8
# CapacityYear                                           2004
# Technology                             Hydro, Small (<50MW)
# ContractHistory                                         NaN
# RelatedProjects                                         NaN
# BidCriteria                Highest price paid to government
# AwardMethod                             Competitive bidding
# NumberOfBids                                            NaN
# NumberRenewalBids                                       NaN
# Sponsors                                 Others (100% / ..)
# MultiLateralSupport                                     NaN
# Revenue Source                                          NaN
# RenewalBidCriteria                                      NaN
# RenewalAwardMethod                                      NaN
# DevelopmentStage                          Financial Closure
# CommissioningDate                                       NaN
# ProjectGrid                                             NaN
# CarbonCredits                                           NaN
# FundingYear                                             NaN
# PrivateFunding                                          NaN
# PublicFunding                                           NaN
# GovtFunding                                             NaN
# BankLocalFunding                                        NaN
# DonorFunding                                            NaN
# DebtEquityGrantRatio                                    NaN
# Name: 200, dtype: object

# %%
##rename features we found to match our schema

private.rename(columns= {'Country': 'country',
 'Financial closure year': 'policy_financing_period_start',
 'Project name' : 'name',
 'Project status': 'policy_status',
 'Primary sector': 'policy_target',
 'TerminationYear': 'policy_implementation_period_end_year',
 'GovtGrantingContract': 'jurisdiction',
 'InvestmentYear': 'policy_financing_period_start',
 'TotalInvestment': 'policy_financing_quantity',
 'CapacityYear': 'policy_implementation_period_start_year'},inplace=True)

# %%
### we dont actually want to drop funding year, need to resolve some of these. 
private.drop(['projectID',
       'Region',
       'IncomeGroup',
       'IDA Status',
       'Financial closure Month',
       'RelatedNames',
       'Type of PPI',
       'Subtype of PPI',
       'Secondary sector',
       'Subsector',
       'Segment',
       'Location',
       'ContractPeriod',
       'PubliclyTraded',
       'StockExchange',
       'MultipleSystems',
       'NumberOfSystems',
       'CaptiveFacility',
       'SharePercent',
       'TypeOfGovtSupport',
       'PercentPrivate',
       'GovtPaymentCommitments',
       'PhysicalAssets',
       'CapacityType',
       'Capacity',
       'Technology',
       'ContractHistory',
       'RelatedProjects',
       'BidCriteria',
       'AwardMethod',
       'NumberOfBids',
       'NumberRenewalBids',
       'Sponsors',
       'MultiLateralSupport',
       'Revenue Source',
       'RenewalBidCriteria',
       'RenewalAwardMethod',
       'DevelopmentStage',
       'CommissioningDate',
       'ProjectGrid',
       'CarbonCredits',
       'FundingYear',
       'PrivateFunding',
       'PublicFunding',
       'GovtFunding',
       'BankLocalFunding',
       'DonorFunding',
       'DebtEquityGrantRatio',
       'GovCashAssist',
       'dateStatusUpdated'
      ], axis=1, inplace=True)

# %%
#add missign features

private['related_documents'] = np.nan
private['policy_type'] = np.nan
private['impact_on_eu_ets_esd_or_lulucf_emissions'] = np.nan
private['total_ghg_emissions_reductions_in_2020'] = np.nan
private['total_ghg_emissions_reductions_in_2030'] = np.nan
private['agency'] = np.nan
private['related_to_eu_policy_boolean'] = np.nan
private['related_to_eu_policy'] = np.nan
private['ghgs_affected'] = np.nan
private['description'] = np.nan
private['link'] = np.nan
private['data_source'] = np.nan
private['world_region'] = np.nan
private['country_region'] = np.nan
private['city'] = np.nan
private['policy_written_year'] = np.nan
private['impact_evaluation'] = np.nan
private['policy_financing_period_end'] = np.nan
private['percent_private_funded'] = np.nan
private['related_to_neeap_policy'] = np.nan
private['related_to_neeap_policy_boolean'] = np.nan


private.columns.tolist()
# Out:
# ['country',
#  'policy_financing_period_start',
#  'name',
#  'policy_status',
#  'policy_target',
#  'policy_implementation_period_end_year',
#  'jurisdiction',
#  'policy_financing_period_start',
#  'policy_financing_quantity',
#  'policy_implementation_period_start_year',
#  'related_documents',
#  'policy_type',
#  'impact_on_eu_ets_esd_or_lulucf_emissions',
#  'total_ghg_emissions_reductions_in_2020',
#  'total_ghg_emissions_reductions_in_2030',
#  'agency',
#  'related_to_eu_policy_boolean',
#  'related_to_eu_policy',
#  'ghgs_affected',
#  'description',
#  'link',
#  'data_source',
#  'world_region',
#  'country_region',
#  'city',
#  'policy_written_year',
#  'impact_evaluation',
#  'policy_financing_period_end',
#  'percent_private_funded',
#  'related_to_neeap_policy',
#  'related_to_neeap_policy_boolean']

# %%
private.to_csv(path_or_buf='data/private_db.csv', index=False)

# %% [markdown]
# ## Climate Change Laws of the World

# %% [markdown]
# ### How this dataset was originated:
# Climate change Laws of the World and Climate Change Litigation of the World build on several years of data collection by both the Grantham Research Institute and the Sabin Center, including the collaboration of Grantham Institute with GLOBE International on a series of Climate Legislation Studies.<sup>1</sup>
# '
#
# As of March 2017, the climate legislation database consists of 1,261 climate change laws or policies
# of similar relevance in 164 jurisdictions (163 countries and the European Union as a bloc). The
# climate change legislation data are maintained and updated regularly by a team at the Grantham
# Research Institute.<sup>2</sup>
#
#
# ### How we got this data:
#
# We used a csv export from the database website here: http://www.lse.ac.uk/GranthamInstitute/legislation/ and then used pandas to extract relevant features to our database.
#
# ___
# <sup>1</sup>Climate Change Laws of the World database, Grantham Research Institute on Climate Change and the Environment and Sabin Center for Climate Change Law. Available at: http://www.lse.ac.uk/GranthamInstitute/legislation/.
#
# <sup>2</sup>Global trends in climate change legislation and litigation: 2017 update. Available at: http://www.lse.ac.uk/GranthamInstitute/wp-content/uploads/2017/04/Global-trends-in-climate-change-legislation-and-litigation-WEB.pdf

# %%
#need to decide how to view "year passed" or think of using this in a seperate comparison type format

laws_db = pd.read_csv('data/source/legislation.csv')
# Out:
# Country                                                        Netherlands
# Name                     National Climate Agenda: Resilient, Prosperous...
# Year Passed                                                           2013
# Executive/Legislative                                            Executive
# Framework                                        Mitigation and adaptation
# Categories               Adaptation; Carbon Pricing; Energy Demand; Ene...
# Document Type                                                       Policy
# Name: 500, dtype: object

# %%
laws_db.columns.tolist()
# Out:
# ['Country',
#  'Name',
#  'Year Passed',
#  'Executive/Legislative',
#  'Framework',
#  'Categories',
#  'Document Type']

# %%
laws_db.rename(columns={
    'Country':'country',
    'Name':'name',
    'Year Passed':,
    'Executive/Legislative',
    'Framework',
    'Categories',
    'Document Type'})

['country',
 'name',
 'related_documents',
 'policy_type',
 'policy_status',
 'impact_on_eu_ets_esd_or_lulucf_emissions',
 'policy_target',
 'total_ghg_emissions_reductions_in_2020',
 'total_ghg_emissions_reductions_in_2030',
 'jurisdiction',
 'agency',
 'policy_implementation_period_start_year',
 'related_to_eu_policy_boolean',
 'related_to_eu_policy',
 'ghgs_affected',
 'description',
 'policy_implementation_period_end_year',
 'link',
 'data_source',
 'world_region',
 'country_region',
 'city',
 'policy_written_year',
 'impact_evaluation',
 'policy_financing_quantity',
 'policy_financing_period_start',
 'policy_financing_period_end',
 'percent_private_funded',
 'related_to_neeap_policy',
 'related_to_neeap_policy_boolean']

# %% [markdown]
# ## DSIRE

# %% [markdown]
# ### How this dataset was originated:
#
# DSIRE – the Database of State Incentives for Renewables & Efficiency – is the most comprehensive source of information on incentives and policies that support renewables and energy efficiency at the federal, state, local, and utility levels.<sup>1</sup>
#
# DSIRE is operated by the N.C. Clean Energy Technology Center at N.C. State University and is funded by the U.S. Department of Energy. It is currently maintained and kept up to date (through 2019) by researchers at the N.C. Clean Energy Technoology
#
# ___
# <sup>1</sup>“DSIRE.” NC Clean Energy Technology Center. Retrieved October 8, 2019 (https://nccleantech.ncsu.edu/resources/dsire/)

# %% [markdown]
# ### How we got this data:
# Sourcing the data from the DSRE used copy and paste for the summary table of all entries in the database into google sheets, which had individual entry urls nested. The sheet can be found here https://docs.google.com/spreadsheets/d/1ouU2GKq2jG928Ds0mez2DL0Slg3GURoW7qPua8rkGIQ/edit#gid=0. After exporting the sheet to html, the nested urls or each entry were extracted using BeautifulSoup along with other relevant features from each dataset entry. Each invidiual entry url was then scraped and its relevant features were concatenated with the corresponding data in the summary row.
#
# Scraping the individual entrys in the database required making a GET request for each, downloading the html, and extracting the json data used to populate the web entry.

# %%
#get individual links
with open("data/source/dsireindex.html", "r") as f:
    
    contents = f.read()

    soup = BeautifulSoup(contents, 'lxml')

all_entries = soup.find_all("tr")
len(all_entries)
# Out:
# 2467

# %%
all_entries[1:3]
# Out:
# [<tr style="height:20px;"><th class="row-headers-background" id="0R0" style="height: 20px;"><div class="row-header-wrapper" style="line-height: 20px;">1</div></th><td class="s0" dir="ltr"><a href="https://programs.dsireusa.org/system/program/detail/1893" target="_blank">Building Requirements for State-Funded Buildings</a></td><td class="s1" dir="ltr">NH</td><td class="s2 softmerge" dir="ltr"><div class="softmerge-inner" style="width: 99px; left: -3px;">Regulatory Policy</div></td><td class="s3 softmerge" dir="ltr"><div class="softmerge-inner" style="width: 99px; left: -3px;">Energy Standards for Public Buildings</div></td><td class="s4" dir="ltr">07/30/2006</td><td class="s4" dir="ltr">10/28/2019</td></tr>,
#  <tr style="height:20px;"><th class="row-headers-background" id="0R1" style="height: 20px;"><div class="row-header-wrapper" style="line-height: 20px;">2</div></th><td class="s5" dir="ltr"><a href="https://programs.dsireusa.org/system/program/detail/85" target="_blank">Local Option - Residential Property Tax Exemption for Solar</a></td><td class="s6" dir="ltr">VA</td><td class="s7 softmerge" dir="ltr"><div class="softmerge-inner" style="width: 99px; left: -3px;">Financial Incentive</div></td><td class="s8 softmerge" dir="ltr"><div class="softmerge-inner" style="width: 99px; left: -3px;">Property Tax Incentive</div></td><td class="s9" dir="ltr">01/01/2000</td><td class="s9" dir="ltr">10/11/2019</td></tr>]

# %%
#build dataset
dsr_complete = []
dsre_links = []

for i in range(1, len(all_entries)):
    dsre_entries = {}
    features = all_entries[i]
    col = features.find_all('td')
    link = col[0].find('a')['href']
    
    #add to link store
    dsre_links.append(link)
    
    #build features
    dsre_entries['country'] = 'United States'
    dsre_entries['name'] = col[0].text
    dsre_entries['related_documents'] = np.nan
    dsre_entries['policy_type'] = col[2].text
    dsre_entries['impact_on_eu_ets_esd_or_lulucf_emissions'] = np.nan
    dsre_entries['total_ghg_emissions_reductions_in_2020'] = np.nan
    dsre_entries['total_ghg_emissions_reductions_in_2030'] = np.nan
    dsre_entries['url'] = link
    dsre_entries['related_to_eu_policy_boolean'] = np.nan
    dsre_entries['related_to_eu_policy'] = np.nan
    dsre_entries['ghgs_affected'] = np.nan
    dsre_entries['data_source'] = 'DSIRE'
    dsre_entries['world_region'] = 'North America'
    dsre_entries['policy_written_year'] = np.nan
    dsre_entries['impact_evaluation'] = np.nan
    dsre_entries['policy_financing_quantity'] = np.nan
    dsre_entries['policy_financing_period_start'] = np.nan
    dsre_entries['policy_financing_period_end'] = np.nan
    dsre_entries['percent_private_funded'] = np.nan
    dsre_entries['related_to_neeap_policy'] = np.nan
    dsre_entries['related_to_neeap_policy_boolean'] = False
    dsre_entries['city'] = np.nan
    dsre_entries['policy_target'] = np.nan

    dsr_complete.append(dsre_entries)

len(dsr_complete)
# Out:
# 2466

# %%
dsr_complete[0:6]
# Out:
# [{'city': nan,
#   'country': 'United States',
#   'data_source': 'DSIRE',
#   'ghgs_affected': nan,
#   'impact_evaluation': nan,
#   'impact_on_eu_ets_esd_or_lulucf_emissions': nan,
#   'name': 'Building Requirements for State-Funded Buildings',
#   'percent_private_funded': nan,
#   'policy_financing_period_end': nan,
#   'policy_financing_period_start': nan,
#   'policy_financing_quantity': nan,
#   'policy_target': nan,
#   'policy_type': 'Regulatory Policy',
#   'policy_written_year': nan,
#   'related_documents': nan,
#   'related_to_eu_policy': nan,
#   'related_to_eu_policy_boolean': nan,
#   'related_to_neeap_policy': nan,
#   'related_to_neeap_policy_boolean': False,
#   'total_ghg_emissions_reductions_in_2020': nan,
#   'total_ghg_emissions_reductions_in_2030': nan,
#   'url': 'https://programs.dsireusa.org/system/program/detail/1893',
#   'world_region': 'North America'},
#  {'city': nan,
#   'country': 'United States',
#   'data_source': 'DSIRE',
#   'ghgs_affected': nan,
#   'impact_evaluation': nan,
#   'impact_on_eu_ets_esd_or_lulucf_emissions': nan,
#   'name': 'Local Option - Residential Property Tax Exemption for Solar',
#   'percent_private_funded': nan,
#   'policy_financing_period_end': nan,
#   'policy_financing_period_start': nan,
#   'policy_financing_quantity': nan,
#   'policy_target': nan,
#   'policy_type': 'Financial Incentive',
#   'policy_written_year': nan,
#   'related_documents': nan,
#   'related_to_eu_policy': nan,
#   'related_to_eu_policy_boolean': nan,
#   'related_to_neeap_policy': nan,
#   'related_to_neeap_policy_boolean': False,
#   'total_ghg_emissions_reductions_in_2020': nan,
#   'total_ghg_emissions_reductions_in_2030': nan,
#   'url': 'https://programs.dsireusa.org/system/program/detail/85',
#   'world_region': 'North America'},
#  {'city': nan,
#   'country': 'United States',
#   'data_source': 'DSIRE',
#   'ghgs_affected': nan,
#   'impact_evaluation': nan,
#   'impact_on_eu_ets_esd_or_lulucf_emissions': nan,
#   'name': 'Town of Chapel Hill - Energy Conservation Requirements for Town Buildings',
#   'percent_private_funded': nan,
#   'policy_financing_period_end': nan,
#   'policy_financing_period_start': nan,
#   'policy_financing_quantity': nan,
#   'policy_target': nan,
#   'policy_type': 'Regulatory Policy',
#   'policy_written_year': nan,
#   'related_documents': nan,
#   'related_to_eu_policy': nan,
#   'related_to_eu_policy_boolean': nan,
#   'related_to_neeap_policy': nan,
#   'related_to_neeap_policy_boolean': False,
#   'total_ghg_emissions_reductions_in_2020': nan,
#   'total_ghg_emissions_reductions_in_2030': nan,
#   'url': 'https://programs.dsireusa.org/system/program/detail/391',
#   'world_region': 'North America'},
#  {'city': nan,
#   'country': 'United States',
#   'data_source': 'DSIRE',
#   'ghgs_affected': nan,
#   'impact_evaluation': nan,
#   'impact_on_eu_ets_esd_or_lulucf_emissions': nan,
#   'name': 'High-Performance Building Requirements for State Buildings',
#   'percent_private_funded': nan,
#   'policy_financing_period_end': nan,
#   'policy_financing_period_start': nan,
#   'policy_financing_quantity': nan,
#   'policy_target': nan,
#   'policy_type': 'Regulatory Policy',
#   'policy_written_year': nan,
#   'related_documents': nan,
#   'related_to_eu_policy': nan,
#   'related_to_eu_policy_boolean': nan,
#   'related_to_neeap_policy': nan,
#   'related_to_neeap_policy_boolean': False,
#   'total_ghg_emissions_reductions_in_2020': nan,
#   'total_ghg_emissions_reductions_in_2030': nan,
#   'url': 'https://programs.dsireusa.org/system/program/detail/3013',
#   'world_region': 'North America'},
#  {'city': nan,
#   'country': 'United States',
#   'data_source': 'DSIRE',
#   'ghgs_affected': nan,
#   'impact_evaluation': nan,
#   'impact_on_eu_ets_esd_or_lulucf_emissions': nan,
#   'name': 'City of St. Louis - Green Building Standard',
#   'percent_private_funded': nan,
#   'policy_financing_period_end': nan,
#   'policy_financing_period_start': nan,
#   'policy_financing_quantity': nan,
#   'policy_target': nan,
#   'policy_type': 'Regulatory Policy',
#   'policy_written_year': nan,
#   'related_documents': nan,
#   'related_to_eu_policy': nan,
#   'related_to_eu_policy_boolean': nan,
#   'related_to_neeap_policy': nan,
#   'related_to_neeap_policy_boolean': False,
#   'total_ghg_emissions_reductions_in_2020': nan,
#   'total_ghg_emissions_reductions_in_2030': nan,
#   'url': 'https://programs.dsireusa.org/system/program/detail/5923',
#   'world_region': 'North America'},
#  {'city': nan,
#   'country': 'United States',
#   'data_source': 'DSIRE',
#   'ghgs_affected': nan,
#   'impact_evaluation': nan,
#   'impact_on_eu_ets_esd_or_lulucf_emissions': nan,
#   'name': 'City of Boston - Green Building Standard',
#   'percent_private_funded': nan,
#   'policy_financing_period_end': nan,
#   'policy_financing_period_start': nan,
#   'policy_financing_quantity': nan,
#   'policy_target': nan,
#   'policy_type': 'Regulatory Policy',
#   'policy_written_year': nan,
#   'related_documents': nan,
#   'related_to_eu_policy': nan,
#   'related_to_eu_policy_boolean': nan,
#   'related_to_neeap_policy': nan,
#   'related_to_neeap_policy_boolean': False,
#   'total_ghg_emissions_reductions_in_2020': nan,
#   'total_ghg_emissions_reductions_in_2030': nan,
#   'url': 'https://programs.dsireusa.org/system/program/detail/5919',
#   'world_region': 'North America'}]

# %%
#test detail

link = dsr_complete[1]['url']

dsre_entries = {}
#get individual entry details
detail = session.get(link)
soup_det = BeautifulSoup(detail.text, 'html.parser')

det_data = soup_det.find('div', attrs={"data-ng-controller": "DetailsPageCtrl"})
det_get = det_data.get('data-ng-init')[5:-1]
json_det = json.loads(det_get)

#save link for merge on link
dsre_entries['url'] = link

dsre_entries['jurisdiction'] = json_det['program']['sectorObj']['name']

if json_det['authorities'][0]['effectiveText'] is not '' or  ' ':
    dsre_entries['policy_implementation_period_start_year'] = json_det['authorities'][0]['effectiveText'][-4:]
else: 
    dsre_entries['policy_implementation_period_start_year'] = json_det['authorities'][0]['enactedText'][-4:]

if json_det['authorities'][0]['expiredText'] is not '':
    dsre_entries['policy_status'] = 'Ended'
    dsre_entries['policy_implementation_period_end_year'] = json_det['authorities'][0]['expiredText']

else:   
    dsre_entries['policy_status'] = 'Active'
    dsre_entries['policy_implementation_period_end_year'] = np.nan
    
dsre_entries['last_updated'] = json_det['program']['lastUpdated']
dsre_entries['country_region'] = json_det['program']['stateObj']['name']
dsre_entries['description'] = json_det['program']['summary']
dsre_entries['link'] = json_det['program']['websiteUrl']

dsre_entries['agency'] = json_det['program']['administrator']

# %%
dsre_entries
# Out:
# {'agency': 'Virginia Department of Mines, Minerals, and Energy',
#  'country_region': 'Virginia',
#  'description': '<p>&#10;&#9;The State of Virginia provides the option for any county, city, or town to exempt or partially exempt solar energy equipment and recycling equipment from local property taxes. \xa0This status is targeted toward non-commercial participants; commercial entities are fully exempt from state and local taxes under <a href="https://programs.dsireusa.org/system/program/detail/5503">Commercial Property Tax Exemption for Solar</a>.</p>&#10;<p>&#10;&#9;The solar equipment and installation has to be inspected and certified by the local building department or the Department of Environmental Quality to provide the value of the system for the purpose of determining tax credit.\xa0<span>The statute broadly defines solar energy equipment as any that is &#34;designed and used primarily for the purpose of collecting, generating, transferring, or storing thermal or electric energy.&#34; This includes solar photovoltaic (PV), solar thermal heating, and passive solar systems.</span></p>&#10;<p>&#10;&#9;Recycling equipment is defined as equipment which is &#34;certified by the Department of Environmental Quality as integral to the recycling process and for use primarily for the purpose of abating or preventing pollution of the atmosphere or waters.</p>&#10;<p>&#10;&#9;Cities currently offering a solar energy equipment and facilities exemption include: Alexandria, Charlottesville, Fredericksburg, Hampton, Harrisonburg, Lexington, Lynchburg, Petersburg, Roanoke, Suffolk, and Winchester.\xa0</p><p><span>Counties currently offering a solar energy equipment and facilities exemption include: Albemarle, Augusta, Botetourt, Chesterfield, Dinwiddie, Fairfax, Frederick, Giles, Hanover, Isle of Wight, King George, Loudoun, Prince William, Pulaski, Scott, Spotsylvania, Warren, and Wise.</span></p><p>\xa0Please contact your local building inspection officials to check if the exemption is offered in your locality.\xa0</p>',
#  'jurisdiction': 'State',
#  'last_update': 'October 11, 2019',
#  'last_updated': 'October 11, 2019',
#  'link': 'http://www.dmme.virginia.gov/DE/Energy_Incentives.shtml',
#  'policy_implementation_period_end_year': nan,
#  'policy_implementation_period_start_year': '1977',
#  'policy_status': 'Active',
#  'url': 'https://programs.dsireusa.org/system/program/detail/85'}

# %%
#use threaded approach like above to compile all entries
det = []

async def main():
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:

        loop = asyncio.get_event_loop()
        futures = [
            loop.run_in_executor(
                executor, 
                session.get, 
                link
            )
            for link in dsre_links
        ]
        
        for response in await asyncio.gather(*futures):
            
            dsre_entries = {}
            #get individual entry details
            soup_det = BeautifulSoup(response.text, 'html.parser')

            det_data = soup_det.find('div', attrs={"data-ng-controller": "DetailsPageCtrl"})
            det_get = det_data.get('data-ng-init')[5:-1]
            json_det = json.loads(det_get)

            #save link for merge on link
            dsre_entries['url'] = link

            dsre_entries['jurisdiction'] = json_det['program']['sectorObj']['name']
            
            if len(json_det['authorities']) == 0:
                dsre_entries['policy_implementation_period_start_year'] = np.nan
                dsre_entries['policy_status'] = np.nan
                dsre_entries['policy_implementation_period_end_year'] = np.nan
                
            
            else:

                if json_det['authorities'][0]['effectiveText'] is not '' or ' ':
                    dsre_entries['policy_implementation_period_start_year'] = json_det['authorities'][0]['effectiveText']
                else: 
                    dsre_entries['policy_implementation_period_start_year'] = json_det['authorities'][0]['enactedText']

                if json_det['authorities'][0]['expiredText'] is not '':
                    dsre_entries['policy_status'] = 'Ended'
                    dsre_entries['policy_implementation_period_end_year'] = json_det['authorities'][0]['expiredText']

                else:   
                    dsre_entries['policy_status'] = 'Active'
                    dsre_entries['policy_implementation_period_end_year'] = np.nan

            dsre_entries['last_updated'] = json_det['program']['lastUpdated']
            dsre_entries['country_region'] = json_det['program']['stateObj']['name']
            dsre_entries['description'] = json_det['program']['summary']
            dsre_entries['link'] = json_det['program']['websiteUrl']

            dsre_entries['agency'] = json_det['program']['administrator']
            
            det.append(dsre_entries)


loop = asyncio.get_event_loop()            
loop.run_until_complete(main())

# %%
#should match the number in the summary list
print(len(dsr_complete))
print(len(det))
# Out:
# 2466
# 2466

# %%
#merge details with summary entries (on url) and drop last update and link we merged on
sum_db = pd.DataFrame(dsr_complete)
det_db = pd.DataFrame(det)

# %%
sum_db.head()
# Out:
#    city        country data_source  ghgs_affected  impact_evaluation  \
# 0   NaN  United States       DSIRE            NaN                NaN
# 1   NaN  United States       DSIRE            NaN                NaN
# 2   NaN  United States       DSIRE            NaN                NaN
# 3   NaN  United States       DSIRE            NaN                NaN
# 4   NaN  United States       DSIRE            NaN                NaN
#
#    impact_on_eu_ets_esd_or_lulucf_emissions  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                                                 name  percent_private_funded  \
# 0   Building Requirements for State-Funded Buildings                     NaN
# 1  Local Option - Residential Property Tax Exempt...                     NaN
# 2  Town of Chapel Hill - Energy Conservation Requ...                     NaN
# 3  High-Performance Building Requirements for Sta...                     NaN
# 4        City of St. Louis - Green Building Standard                     NaN
#
#    policy_financing_period_end  policy_financing_period_start      ...        \
# 0                          NaN                            NaN      ...
# 1                          NaN                            NaN      ...
# 2                          NaN                            NaN      ...
# 3                          NaN                            NaN      ...
# 4                          NaN                            NaN      ...
#
#    policy_written_year  related_documents related_to_eu_policy  \
# 0                  NaN                NaN                  NaN
# 1                  NaN                NaN                  NaN
# 2                  NaN                NaN                  NaN
# 3                  NaN                NaN                  NaN
# 4                  NaN                NaN                  NaN
#
#    related_to_eu_policy_boolean  related_to_neeap_policy  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
#
#    related_to_neeap_policy_boolean  total_ghg_emissions_reductions_in_2020  \
# 0                            False                                     NaN
# 1                            False                                     NaN
# 2                            False                                     NaN
# 3                            False                                     NaN
# 4                            False                                     NaN
#
#    total_ghg_emissions_reductions_in_2030  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                                                  url   world_region
# 0  https://programs.dsireusa.org/system/program/d...  North America
# 1  https://programs.dsireusa.org/system/program/d...  North America
# 2  https://programs.dsireusa.org/system/program/d...  North America
# 3  https://programs.dsireusa.org/system/program/d...  North America
# 4  https://programs.dsireusa.org/system/program/d...  North America
#
# [5 rows x 23 columns]

# %%
det_db.head()
# Out:
#                                               agency  country_region  \
# 0                                               None   New Hampshire
# 1  Virginia Department of Mines, Minerals, and En...        Virginia
# 2                                               None  North Carolina
# 3                                               None    South Dakota
# 4                            Board of Public Service        Missouri
#
#                                          description jurisdiction  \
# 0  <p>New Hampshire enacted legislation (S.B. 409...        State
# 1  <p>&#10;&#9;The State of Virginia provides the...        State
# 2  <p>The Town of Chapel Hill’s energy-conservati...        Local
# 3  <p>&#10;&#9;In March 2008, South Dakota enacte...        State
# 4  <p>This ordinance requires LEED (Leadership in...        Local
#
#          last_updated                                               link  \
# 0    October 28, 2019  https://das.nh.gov/publicworks/High%20Performa...
# 1    October 11, 2019  http://www.dmme.virginia.gov/DE/Energy_Incenti...
# 2     October 7, 2019
# 3  September 30, 2019
# 4  September 30, 2019         https://www.stlouis-mo.gov/sustainability/
#
#   policy_implementation_period_end_year  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                  None
#
#   policy_implementation_period_start_year policy_status  \
# 0                              07/01/2011        Active
# 1                                                Active
# 2                                                Active
# 3                                                Active
# 4                                    None         Ended
#
#                                                  url
# 0  https://programs.dsireusa.org/system/program/d...
# 1  https://programs.dsireusa.org/system/program/d...
# 2  https://programs.dsireusa.org/system/program/d...
# 3  https://programs.dsireusa.org/system/program/d...
# 4  https://programs.dsireusa.org/system/program/d...

# %%
full_dsre = sum_db.merge(det_db, on='url',)

# %%
#set(full_dsre['name'].tolist())

# %%
dsre_full.to_csv(path_or_buf='data/dsire_db.csv', index=False)
